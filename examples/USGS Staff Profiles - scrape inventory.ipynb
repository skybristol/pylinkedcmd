# %% [markdown]
# USGS profile pages represent one of the best and most personally controlled (by individual staff) locations for information about people. Unfortunately, they are part of a "closed" system that supports no real method of accessing content via software. This could be easily and appropriately resolved by embedding structured linked data on the staff profile pages, and alignment with schema.org elements would help to make the content both digestible for code and go a long way to improve public search. In the meantime, I wrote some helper functions to let us get at this information for capacity assessment and other work.
#
# This code sequence handles the process of pulling the full inventory of staff so that we can link together known information found in other sources (email address) with the URL to the relevant staff profile pages. The inventory of staff is found at https://www.usgs.gov/connect/staff-profiles, and we have to walk through all pages from that point to get everyone. This process uses a simple parallel process to do that, hitting each page with a specific scraping function to get every listing from that page and accumulating into a combined list of dictionaries that can be saved out for later uses.

# %%
import pylinkedcmd.pylinkedcmd as l_cmd
from joblib import Parallel, delayed
import tqdm

usgs_web = l_cmd.UsgsWeb()

# %% [markdown]
# The get_staff_inventory_pages() function hits the first page in the staff profile listing and extracts the page number for the last page from a specific link on that page. It then sets up and returns a list of URLs that we need to hit to get everyone.

# %%
inventory_urls = usgs_web.get_staff_inventory_pages()
len(inventory_urls)
# Out:
# 282

# %% [markdown]
# There are lots of ways of handling the data spit out by this process. In this case, everything is pretty small, and we can run the whole process in memory and build a list of all the records we care about. This codeblock sets up the list that we'll build and then provides a simple accumulator function that runs the core function for processing/scraping a given page for its inventory.

# %%
staff_inventory = list()

def accumulator(url):
    staff_inventory.extend(usgs_web.get_staff_listing(url))

# %% [markdown]
# JobLib is a Python package for running simple parallel processes over lists/batches of stuff we need to process. In this case, I set it to use threads and send 10 URLs at a time from our list to accumulate into the inventory. The tqdm package does a nice job of giving me a status of how far along the process is.

# %%
# %%time
Parallel(n_jobs=20, prefer="threads")(
    delayed(accumulator)
    (
        i
    ) for i in tqdm.tqdm(inventory_urls)
)
# Out:
# 100%|██████████| 282/282 [00:22<00:00, 12.37it/s]
# CPU times: user 24.1 s, sys: 1.1 s, total: 25.2 s
# Wall time: 25.4 s
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# In working through the data that come back from this scraping exercise, I ran into some curious issues that make it a bit difficult to work with the information in some circumstances. I wrote the get_unique_staff function to deal with these and return a workable list of unique staff members and the best available information we can gain from this source.
#
# * There are some cases where there are actual complete duplicate records where all attributes gathered for a given staff listing are the same, and so I reduce those duplicates, assuming these may be artifacts of the pagination mechanism used.
# * There are quite a few cases where there is no email address available for the person. Many of these do have a profile page, and in checking those, I also see that no email is listed. Those individuals (or at least most of them) do have an email address in our main directory resource (publicly available on ScienceBase), and I do not know why their emails have been excluded from the staff profile system. There's not a lot we can do with these records in terms of linking them to other sources without some conjecture. To deal with this here, I assign an "identifier" property in the scraping process that is either email or name, except for another corner case where different people are using a common email (ask@usgs.gov is the only one so far). This lets me group other properties together on those somewhat unique values. The reason that I did not use profile URL as a possible identifier is that there are cases where the same individual has two profile pages.
# * Some individuals do appear to have more than one profile page in the system for what is actually the same person. I assume this is actually a mistake or problem in the data platform behind this as looking through some of these cases (one where the same person apparently has 7 profile pages), I see matching other details (email and telephone) with one profile page populated and another not. My guess is that the system used for people to create their profile pages has some problems (or has in the past) that will need to be cleaned up.
#
# To deal with these all these issues, and come up with an actionable inventory, I weed out duplicate full records, read the list of dictionaries into a Pandas dataframe, group by the identifier property putting everything else into lists of unique values, and the send it back out as either a dataframe or list of dictionaries. This means we need to process everything as lists when most properties are discrete values, but we have what we need to tie this information to other data sources.
#
# Along the way of looking through these data, I did run into a couple issues in string values picked up. A couple of them look like HTML output artifacts, but there are a few cases where it appears that the data are likely a little wonky coming from the source. I presume that we have some kind of database where the profile/staff inventory information lives. Perhaps it's directly within the Drupal framework that manages the USGS web sites now. I'm guessing there is also no utility on that end that is making sure all the information in that database aligns with something like the DOI Active Directory, which would be a logical connecting point. This is, again, an area where we need to do some cleanup, maintenance, and consistency checks across all the systems that make up our Corporate Master Data in the absence of a single unifying system that everything uses.

# %%
unique_staff_inventory = usgs_web.get_unique_staff(staff_inventory)

# %% [markdown]
# To demonstrate some of the issues, here's a list of what appear to be the same staff person with multiple profile pages. We'll have to treat these cases with some care and decide what to do about the content we can gather.

# %%
[i for i in unique_staff_inventory if len(i["profile"]) > 1]
# Out:
# [{'identifier': 'acbooth@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/amanda-c-booth',
#    'https://usgs.gov/staff-profiles/amanda-booth'],
#   'email': ['acbooth@usgs.gov'],
#   'name': ['Amanda Booth', 'Amanda C Booth'],
#   'organization_name': ['Caribbean Florida Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water', None],
#   'telephone': ['239-275-8448'],
#   'title': ['Physical Scientist']},
#  {'identifier': 'acgill@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/amy-gill',
#    'https://usgs.gov/staff-profiles/amy-c-gill'],
#   'email': ['acgill@usgs.gov'],
#   'name': ['Amy Gill', 'Amy C Gill'],
#   'organization_name': ['Lower Mississippi-Gulf Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/lmg-water'],
#   'telephone': ['334-395-4128'],
#   'title': ['Hydrologist']},
#  {'identifier': 'ackarlson@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/andrew-c-karlson',
#    'https://usgs.gov/staff-profiles/andrew-karlson'],
#   'email': ['ackarlson@usgs.gov'],
#   'name': ['Andrew Karlson', 'Andrew C Karlson'],
#   'organization_name': ['Utah Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/ut-water'],
#   'telephone': ['801-908-5063'],
#   'title': ['Hydrologic Technician, Salt Lake City Field Office',
#    'Hydrologic Technician']},
#  {'identifier': 'akvaughan@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/dawn-l-hemmerle-0',
#    'https://usgs.gov/staff-profiles/allison-k-vaughan'],
#   'email': ['akvaughan@usgs.gov'],
#   'name': ['ALLISON K Vaughan', 'Dawn L Hemmerle'],
#   'organization_name': ['Water Resources Mission Area'],
#   'organization_link': ['https://www.usgs.gov/mission-areas/water-resources'],
#   'telephone': ['303-236-3444'],
#   'title': ['Chemist']},
#  {'identifier': 'astro_outreach@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/brent-archinal-0',
#    'https://usgs.gov/staff-profiles/laurence-soderblom'],
#   'email': ['astro_outreach@usgs.gov'],
#   'name': ['Laurence  Soderblom, PhD', 'Brent Archinal, PhD'],
#   'organization_name': ['Astrogeology Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/astrogeology-science-center'],
#   'telephone': ['555-555-5555'],
#   'title': ['Research Geodesist', 'Geophysicist']},
#  {'identifier': 'avanover@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/andrew-vanover-0',
#    'https://usgs.gov/staff-profiles/andrew-vanover'],
#   'email': ['avanover@usgs.gov'],
#   'name': ['Andrew Vanover', 'Andrew  Vanover'],
#   'organization_name': ['Ohio Kentucky Indiana Water Science Center',
#    'Lower Mississippi-Gulf Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/lmg-water/',
#    'https://www.usgs.gov/centers/oki-water'],
#   'telephone': ['334-395-4129', '502-493-1918'],
#   'title': ['Hydrologic Technician']},
#  {'identifier': 'bjohnsto@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/brett-johnston',
#    'https://usgs.gov/staff-profiles/brett-d-johnston'],
#   'email': ['bjohnsto@usgs.gov'],
#   'name': ['Brett Johnston', 'Brett D Johnston'],
#   'organization_name': ['Caribbean Florida Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water', None],
#   'telephone': ['407-803-5547'],
#   'title': ['Hydrologic Technician']},
#  {'identifier': 'bjstolp@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/bert-stolp',
#    'https://usgs.gov/staff-profiles/bernard-j-stolp'],
#   'email': ['bjstolp@usgs.gov'],
#   'name': ['Bernard J Stolp', 'Bert Stolp'],
#   'organization_name': ['Utah Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/ut-water'],
#   'telephone': ['801-908-5061'],
#   'title': ['Hydrologist', 'Scientist Emeritus']},
#  {'identifier': 'cculbert@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/charles-w-culbertson-0',
#    'https://usgs.gov/staff-profiles/charles-w-culbertson'],
#   'email': ['cculbert@usgs.gov'],
#   'name': ['Charles W Culbertson'],
#   'organization_name': ['New England Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/new-england-water'],
#   'telephone': ['207-626-6627'],
#   'title': ['Scientist Emeritus']},
#  {'identifier': 'cmhobza@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/chris-hobza',
#    'https://usgs.gov/staff-profiles/christopher-hobza'],
#   'email': ['cmhobza@usgs.gov'],
#   'name': ['Christopher Hobza', 'Chris Hobza'],
#   'organization_name': ['Nebraska Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/ne-water'],
#   'telephone': ['402-328-4133'],
#   'title': ['Hydrologist', 'Lead Hydrologist']},
#  {'identifier': 'cokubo@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/chris-obuko',
#    'https://usgs.gov/staff-profiles/chris-h-okubo'],
#   'email': ['cokubo@usgs.gov'],
#   'name': ['Chris Obuko', 'Chris H Okubo, PhD'],
#   'organization_name': ['Astrogeology Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/astrogeology-science-center',
#    None],
#   'telephone': ['928-556-7015', '928-556-7009'],
#   'title': ['Research Geophysicist',
#    'Deputy Center Director and Research Operations Lead']},
#  {'identifier': 'destraub@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/david-straub',
#    'https://usgs.gov/staff-profiles/dave-straub'],
#   'email': ['destraub@usgs.gov'],
#   'name': ['David Straub', 'Dave Straub'],
#   'organization_name': [None, 'Ohio-Kentucky-Indiana Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/oki-water', None],
#   'telephone': ['614-430-7744'],
#   'title': ['Science Chief / Supervisory Hydrologist',
#    'Hydrologist (Engineer)']},
#  {'identifier': 'dgarcia@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/dario-garcia',
#    'https://usgs.gov/staff-profiles/diane-garcia'],
#   'email': ['dgarcia@usgs.gov'],
#   'name': ['Dario Garcia', 'Diane Garcia'],
#   'organization_name': ['Office of Communications and Publishing',
#    'Western Geographic Science Center'],
#   'organization_link': ['https://www.usgs.gov/about/organization/science-support/communications-and-publi...',
#    'https://www.usgs.gov/centers/wgsc'],
#   'telephone': ['650-329-5305', '650-329-4382'],
#   'title': ['Chief, Science Information Services', 'IT Specialist']},
#  {'identifier': 'dhubbell@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/derrick-hubbell',
#    'https://usgs.gov/staff-profiles/derrick-l-hubbell'],
#   'email': ['dhubbell@usgs.gov'],
#   'name': ['Derrick Hubbell', 'Derrick L Hubbell'],
#   'organization_name': ['Upper Midwest Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/umid-water', None],
#   'telephone': ['517-887-8944'],
#   'title': ['Supervisory Hydrologic Technician, Field Office Chief']},
#  {'identifier': 'djorde@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/dennis-g-jorde-0',
#    'https://usgs.gov/staff-profiles/dennis-g-jorde'],
#   'email': ['djorde@usgs.gov'],
#   'name': ['Dennis G Jorde'],
#   'organization_name': ['Patuxent Wildlife Research Center'],
#   'organization_link': ['https://www.usgs.gov/centers/pwrc'],
#   'telephone': ['304-724-4401'],
#   'title': ['Scientist Emeritus']},
#  {'identifier': 'ekilburn@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/evan-kilburn',
#    'https://usgs.gov/staff-profiles/evan-kilburn-0'],
#   'email': ['ekilburn@usgs.gov'],
#   'name': ['Evan  Kilburn', 'Evan Kilburn'],
#   'organization_name': ['Lower Mississippi-Gulf Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/lmg-water/',
#    'https://www.usgs.gov/centers/lmg-water'],
#   'telephone': ['334-395-4130'],
#   'title': ['Hydrologic Technician']},
#  {'identifier': 'ffdbg@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/dennis-b-griffith',
#    'https://usgs.gov/staff-profiles/brad-griffith'],
#   'email': ['ffdbg@usgs.gov'],
#   'name': ['Brad Griffith, Ph.D.', 'Dennis B Griffith'],
#   'organization_name': ['Alaska Cooperative Fish and Wildlife Research Unit',
#    None],
#   'organization_link': ['https://www.usgs.gov/ecosystems/cooperative-research-units',
#    None],
#   'telephone': ['907-474-5067'],
#   'title': ['Scientist Emeritus',
#    'Alaska Cooperative Fish and Wildlife Research Unit Leader -- Research Wildlife Biologist']},
#  {'identifier': 'jdixon@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/joann-f-dixon',
#    'https://usgs.gov/staff-profiles/joann-dixon'],
#   'email': ['jdixon@usgs.gov'],
#   'name': ['Joann F Dixon', 'Joann Dixon'],
#   'organization_name': ['Caribbean Florida Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water', None],
#   'telephone': ['jdixon@usgs.gov', '407-803-5533'],
#   'title': ['IT Specialist (GIS)']},
#  {'identifier': 'jdriessen@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/jessica-driessen-1',
#    'https://usgs.gov/staff-profiles/jessica-driessen',
#    'https://usgs.gov/staff-profiles/jessica-driessen-0'],
#   'email': ['jdriessen@usgs.gov'],
#   'name': ['Jessica Driessen'],
#   'organization_name': ['Wyoming-Montana Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/wy-mt-water',
#    'https://www.usgs.gov/centers/wy-mt-water/'],
#   'telephone': ['406-457-5939', '406-459-5939'],
#   'title': ['Office Authomation Clerk', 'Office Automation Clerk']},
#  {'identifier': 'jjason@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/jonathan-w-jason',
#    'https://usgs.gov/staff-profiles/christopher-j-brown',
#    'https://usgs.gov/staff-profiles/jonathan-w-jason-0'],
#   'email': ['jjason@usgs.gov'],
#   'name': ['Jonathan W Jason', 'Christopher J Brown', 'Jonathan  W Jason'],
#   'organization_name': ['South Atlantic Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/sa-water'],
#   'telephone': ['678-924-6633', '678-924-6710'],
#   'title': ['Unknown', 'Hydrologic Technician']},
#  {'identifier': 'jkjoiner@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/john-joiner',
#    'https://usgs.gov/staff-profiles/john-k-joiner'],
#   'email': ['jkjoiner@usgs.gov'],
#   'name': ['John Joiner', 'John  K Joiner'],
#   'organization_name': ['South Atlantic Water Science Center',
#    'South Atlantic Water Science Center - Georgia'],
#   'organization_link': ['https://www.usgs.gov/centers/sa-water'],
#   'telephone': ['678-924-6659'],
#   'title': ['Supervisory Hydrologist', 'Supv. Hydrologist']},
#  {'identifier': 'jskinner@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/james-skinner',
#    'https://usgs.gov/staff-profiles/jim-skinner'],
#   'email': ['jskinner@usgs.gov'],
#   'name': ['James Skinner', 'Jim Skinner'],
#   'organization_name': ['Astrogeology Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/astrogeology-science-center',
#    None],
#   'telephone': ['928-556-7043', '555-555-5555'],
#   'title': ['Research Geologist']},
#  {'identifier': 'jwolf@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/john-wolf',
#    'https://usgs.gov/staff-profiles/john-c-wolf'],
#   'email': ['jwolf@usgs.gov'],
#   'name': ['John Wolf', 'John C Wolf'],
#   'organization_name': ['Lower Mississippi-Gulf Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/lmg-water'],
#   'telephone': ['410-267-5739'],
#   'title': ['Supervisory Geographer']},
#  {'identifier': 'kcollier@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/katie-m-collier',
#    'https://usgs.gov/staff-profiles/lori-j-lewis'],
#   'email': ['kcollier@usgs.gov'],
#   'name': ['Lori J Lewis', 'Katie M Collier'],
#   'organization_name': ['Caribbean Florida Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water'],
#   'telephone': ['850-553-3667', '850-553-3669'],
#   'title': ['Hydrologic Technician']},
#  {'identifier': 'kklass@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/kyle-t-klass',
#    'https://usgs.gov/staff-profiles/kyle-klass'],
#   'email': ['kklass@usgs.gov'],
#   'name': ['Kyle T Klass', 'Kyle Klass'],
#   'organization_name': ['Ohio Kentucky Indiana Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/oki-water', None],
#   'telephone': ['270-759-2460'],
#   'title': ['Hydrologic Technician']},
#  {'identifier': 'kpevans@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/kent-p-evans',
#    'https://usgs.gov/staff-profiles/kent-evans'],
#   'email': ['kpevans@usgs.gov'],
#   'name': ['Kent P Evans', 'Kent Evans'],
#   'organization_name': ['Caribbean Florida Water Science Center',
#    'Caribbean-Florida Water Science Center (CFWSC)'],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water'],
#   'telephone': ['813-498-5067'],
#   'title': ['Supervisory IT Specialist']},
#  {'identifier': 'ldubrow@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/lauren-dubrow',
#    'https://usgs.gov/staff-profiles/lauren-e-dubrow'],
#   'email': ['ldubrow@usgs.gov'],
#   'name': ['Lauren Dubrow', 'Lauren E Dubrow'],
#   'organization_name': ['National Climate Adaptation Science Center'],
#   'organization_link': ['https://www.usgs.gov/land-resources/climate-adaptation-science-centers/north-cen...',
#    'https://www.usgs.gov/land-resources/climate-adaptation-science-centers/national-...'],
#   'telephone': ['703-648-4089'],
#   'title': ['Office Automation Clerk']},
#  {'identifier': 'lrdavis@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/bob-davis',
#    'https://usgs.gov/staff-profiles/larry-davis'],
#   'email': ['lrdavis@usgs.gov'],
#   'name': ['Bob Davis', 'Larry Davis'],
#   'organization_name': [None],
#   'organization_link': [None],
#   'telephone': ['573-308-3554', None],
#   'title': ['Chief of Cartographic Data Services', None]},
#  {'identifier': 'mfield@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/michael-e-field',
#    'https://usgs.gov/staff-profiles/michael-e-field-0'],
#   'email': ['mfield@usgs.gov'],
#   'name': ['Michael E Field'],
#   'organization_name': ['Pacific Coastal & Marine Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/pcmsc'],
#   'telephone': ['831-460-7537'],
#   'title': ['Scientist Emeritus']},
#  {'identifier': 'mmaylone@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/meghan-e-maylone',
#    'https://usgs.gov/staff-profiles/meghan-e-maylone-0'],
#   'email': ['mmaylone@usgs.gov'],
#   'name': ['Meghan E Maylone', 'Meghan  E Maylone'],
#   'organization_name': ['South Atlantic Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/sa-water', None],
#   'telephone': ['678-924-6700'],
#   'title': ['Student Hydrologic Technician', 'Hydrologic Technician']},
#  {'identifier': 'nmillima@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/nolan-d-milliman',
#    'https://usgs.gov/staff-profiles/nolan-douglas-milliman'],
#   'email': ['nmillima@usgs.gov'],
#   'name': ['Nolan  D Milliman', 'Nolan Douglas Milliman'],
#   'organization_name': ['New York Water Science Center',
#    'South Atlantic Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/sa-water',
#    'https://www.usgs.gov/centers/ny-water'],
#   'telephone': ['607-266-0217', '843-762-8655'],
#   'title': ['Unknown', 'Hydrologic Technician']},
#  {'identifier': 'oakuoko@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/ohene-a-akuoko',
#    'https://usgs.gov/staff-profiles/ohene-akuoko'],
#   'email': ['oakuoko@usgs.gov'],
#   'name': ['Ohene A Akuoko', 'Ohene Akuoko'],
#   'organization_name': ['South Atlantic Water Science Center (SAWSC)',
#    'South Atlantic Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/sa-water'],
#   'telephone': ['678-924-6641'],
#   'title': ['Hydrologic Technician']},
#  {'identifier': 'phyoung@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/patrick-young', None],
#   'email': ['phyoung@usgs.gov'],
#   'name': ['Patrick Young', 'Patrick H Young'],
#   'organization_name': ['Patuxent Wildlife Research Center'],
#   'organization_link': ['https://www.usgs.gov/centers/pwrc'],
#   'telephone': ['301-497-5500', '301-497-5719'],
#   'title': ['Admin Pathways Student']},
#  {'identifier': 'rcthomps@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/ryan-f-thompson',
#    'https://usgs.gov/staff-profiles/ryan-f-thompson-0'],
#   'email': ['rcthomps@usgs.gov'],
#   'name': ['Ryan  F Thompson', 'Ryan F Thompson'],
#   'organization_name': ['Dakota Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/dakota-water',
#    'https://www.usgs.gov/centers/oki-water'],
#   'telephone': ['605-352-4241'],
#   'title': ['Hydrologist']},
#  {'identifier': 'rhammerschlag@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/richard-s-hammerschlag-0',
#    'https://usgs.gov/staff-profiles/richard-s-hammerschlag'],
#   'email': ['rhammerschlag@usgs.gov'],
#   'name': ['Richard S Hammerschlag'],
#   'organization_name': ['Patuxent Wildlife Research Center'],
#   'organization_link': ['https://www.usgs.gov/centers/pwrc'],
#   'telephone': ['304-724-4401'],
#   'title': ['Scientist Emeritus']},
#  {'identifier': 'rlotspei@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/robert-r-lotspeich',
#    'https://usgs.gov/staff-profiles/russ-lotspeich'],
#   'email': ['rlotspei@usgs.gov'],
#   'name': ['Robert  R Lotspeich', 'Russ Lotspeich'],
#   'organization_name': ['Virginia and West Virginia Water Science Center',
#    None],
#   'organization_link': ['https://www.usgs.gov/centers/va-wv-water', None],
#   'telephone': ['804-261-2637'],
#   'title': ['Hydrologist', 'Hydrologist, Surface Water Specialist']},
#  {'identifier': 'rmbennett@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/randy-bennett',
#    'https://usgs.gov/staff-profiles/randy-m-bennett'],
#   'email': ['rmbennett@usgs.gov'],
#   'name': ['Randy Bennett, M.B.A.', 'Randy M Bennett'],
#   'organization_name': ['Leetown Science Center',
#    'LSC Aquatic Ecology Laboratory'],
#   'organization_link': ['https://www.usgs.gov/centers/lsc'],
#   'telephone': ['570-724-3322'],
#   'title': ['Scientific Data and Information Management',
#    'Information and Data Management']},
#  {'identifier': 'rstein@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/ross-stein',
#    'https://usgs.gov/staff-profiles/ross-s-stein'],
#   'email': ['rstein@usgs.gov'],
#   'name': ['Ross S Stein', 'Ross Stein'],
#   'organization_name': ['Earthquake Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/earthquake-science-center',
#    None],
#   'telephone': ['650-329-4840'],
#   'title': ['Scientist Emeritus', 'Research Geophysicist']},
#  {'identifier': 'salcalde@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/sharon-m-alcalde',
#    'https://usgs.gov/staff-profiles/sharon-m-alcade'],
#   'email': ['salcalde@usgs.gov'],
#   'name': ['Sharon M Alcade', 'Sharon M Alcalde'],
#   'organization_name': ['Water Resources Mission Area'],
#   'organization_link': ['https://www.usgs.gov/mission-areas/water-resources'],
#   'telephone': ['703-648-5838'],
#   'title': ['Program Analyst']},
#  {'identifier': 'scobern@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/steve-cobern',
#    'https://usgs.gov/staff-profiles/steven-coburn'],
#   'email': ['scobern@usgs.gov'],
#   'name': ['Steve Cobern', 'Steven Coburn'],
#   'organization_name': [None],
#   'organization_link': [None],
#   'telephone': ['919-571-4096', '919-606-5292'],
#   'title': ['IT Specialist']},
#  {'identifier': 'sjolly@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/shelby-jolly',
#    'https://usgs.gov/staff-profiles/shelby-j-jolly'],
#   'email': ['sjolly@usgs.gov'],
#   'name': ['Shelby  J Jolly', 'Shelby Jolly'],
#   'organization_name': ['South Atlantic Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/sa-water', None],
#   'telephone': ['678-924-6641'],
#   'title': ['Student Hydrologic Technician', 'Student']},
#  {'identifier': 'szeigler@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/sara-l-zeigler',
#    'https://usgs.gov/staff-profiles/sara-zeigler'],
#   'email': ['szeigler@usgs.gov'],
#   'name': ['Sara L Zeigler, Ph.D', 'Sara Zeigler'],
#   'organization_name': ['St. Petersburg Coastal and Marine Science Center',
#    None],
#   'organization_link': ['https://www.usgs.gov/centers/whcmsc', None],
#   'telephone': ['508-457-2290'],
#   'title': ['Research Geographer', None]},
#  {'identifier': 'tereilly@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/thomas-e-reilly-5',
#    'https://usgs.gov/staff-profiles/thomas-e-reilly-2',
#    'https://usgs.gov/staff-profiles/thomas-e-reilly-0',
#    'https://usgs.gov/staff-profiles/thomas-e-reilly',
#    'https://usgs.gov/staff-profiles/thomas-e-reilly-3',
#    'https://usgs.gov/staff-profiles/thomas-e-reilly-1',
#    'https://usgs.gov/staff-profiles/thomas-e-reilly-4'],
#   'email': ['tereilly@usgs.gov'],
#   'name': ['Thomas E Reilly'],
#   'organization_name': ['Earth System Processes Division'],
#   'organization_link': ['https://www.usgs.gov/mission-areas/water-resources'],
#   'telephone': ['703-648-6005', '703-648-5281', '703-648-5006'],
#   'title': ['Scientist Emeritus']},
#  {'identifier': 'tjlane@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/theresa-lane',
#    'https://usgs.gov/staff-profiles/t-j-lane'],
#   'email': ['tjlane@usgs.gov'],
#   'name': ['T. J. Lane', 'Theresa Lane'],
#   'organization_name': ['Administration', None],
#   'organization_link': ['https://www.usgs.gov/about/organization/science-support/administration?qt-scienc...=',
#    None],
#   'telephone': ['303-445-4677'],
#   'title': ['Training Systems Specialist']},
#  {'identifier': 'tldalrym@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/timothy-dalrymple',
#    'https://usgs.gov/staff-profiles/timothy-l-dalrymple'],
#   'email': ['tldalrym@usgs.gov'],
#   'name': ['Timothy L Dalrymple', 'Timothy Dalrymple'],
#   'organization_name': ['Caribbean Florida Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water', None],
#   'telephone': ['906-630-0424', '787-749-7414'],
#   'title': ['Supervisory Hydrologic Technician']},
#  {'identifier': 'tneal@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/tina-neal',
#    'https://usgs.gov/staff-profiles/christina-neal'],
#   'email': ['tneal@usgs.gov'],
#   'name': ['Christina Neal', 'Tina Neal'],
#   'organization_name': ['USGS Hawaiian Volcano Observatory',
#    'Hawaiian Volcano Observatory'],
#   'organization_link': ['https://www.usgs.gov/hvo',
#    'https://www.usgs.gov/observatories/hawaiian-volcano-observatory'],
#   'telephone': ['808-967-8853'],
#   'title': ['HVO Scientist in Charge', 'Scientist-in-Charge']},
#  {'identifier': 'tneedham@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/trevor-p-needham-0', None],
#   'email': ['tneedham@usgs.gov'],
#   'name': ['Trevor P Needham', 'Trevor P Needham, PhD'],
#   'organization_name': ['MD-DE-DC Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/md-de-dc-water/', None],
#   'telephone': ['443-498-5584'],
#   'title': ['Hydrologist']},
#  {'identifier': 'wmcbride@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/w-scott-mcbride',
#    'https://usgs.gov/staff-profiles/william-s-mcbride'],
#   'email': ['wmcbride@usgs.gov'],
#   'name': ['William S McBride', 'W. Scott McBride'],
#   'organization_name': ['Caribbean Florida Water Science Center',
#    'Caribbean-Florida Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water'],
#   'telephone': ['813-498-5077'],
#   'title': ['Hydrologist']},
#  {'identifier': 'wwstone@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/wesley-w-stone',
#    'https://usgs.gov/staff-profiles/wesley-stone'],
#   'email': ['wwstone@usgs.gov'],
#   'name': ['Wesley Stone', 'Wesley W Stone'],
#   'organization_name': ['Caribbean-Florida Water Science Center',
#    'Caribbean Florida Water Science Center, Southeast Region'],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water'],
#   'telephone': ['317-600-2786', '813-498-5057'],
#   'title': ['Hydrologist', 'Associate Center Director for Data']},
#  {'identifier': 'yamart@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/yanire-martinez',
#    'https://usgs.gov/staff-profiles/yanire-mart-nez'],
#   'email': ['yamart@usgs.gov'],
#   'name': ['Yanire Martínez', 'Yanire Martinez'],
#   'organization_name': ['Caribbean Florida Water Science Center', None],
#   'organization_link': ['https://www.usgs.gov/centers/car-fl-water', None],
#   'telephone': ['787-749-7451'],
#   'title': ['Hydrologic Technician']},
#  {'identifier': 'zholcomb@usgs.gov',
#   'profile': ['https://usgs.gov/staff-profiles/zachary-thomas-holcomb',
#    'https://usgs.gov/staff-profiles/zack-holcomb'],
#   'email': ['zholcomb@usgs.gov'],
#   'name': ['Zachary Thomas Holcomb', 'Zack Holcomb'],
#   'organization_name': ['Kansas Water Science Center'],
#   'organization_link': ['https://www.usgs.gov/centers/kswsc',
#    'https://www.usgs.gov/centers/lmg-water'],
#   'telephone': ['785-832-3558', '785-832-3516'],
#   'title': ['Hydrologic Technician']}]

# %% [markdown]
# It doesn't take that long to run this, but I'll stick things in a file for later use anyway.

# %%
import pickle

outfile = open("usgs_staff.pkl", "wb")
pickle.dump(unique_staff_inventory, outfile)
outfile.close()
