# %% [markdown]
# One of the use cases we are exploring through this code project is how we can use WikiData to help augment a process for auto-assembling research records for USGS staff. After writing a series of functions for interacting with both the ScienceBase Directory as our starting point, working out linkages to WikiData IDs, and a set of functions for working with WikiData, we can start exploring what routes to useful information WikiData records linked to USGS person records might produce. This notebook works through the necessary functions and provides a comprehensive look at the individual properties of USGS people in WikiData. These properties are considered statements or claims about a person and include identifiers for crossreference to other systems that may also be useful.

# %%
import pylinkedcmd
from IPython.display import display
import time

sb = pylinkedcmd.pylinkedcmd.Sciencebase()
wd = pylinkedcmd.pylinkedcmd.Wikidata()

# %% [markdown]
# First, we need to get relevant person records from the USGS ScienceBase Directory as our starting point. The SB Directory contains a record of everyone who currently works for the USGS or who has worked for the USGS in the years since it was established (~2010). It also contains records for collaborators from other organizations and institutions who have been involved in USGS work and obtained an account with us at some point. It's not a perfect resource, but it represents the best publicly available source of structured information on USGS staff that is reasonably comprehensive. The sb_people function is pretty specialized for our use cases here as it filters to just people with a WikiData ID and simplifies the output to just a select number of fields that we care about for this exercise. The function takes a little bit of time to run through, so we time it for reference.

# %%
# %%time
people = sb.sb_people(fields="simple")
print(len(people))
display(people[99])
# Out:
# 2155
# {'uri': 'https://www.sciencebase.gov/directory/person/4417',
#  'displayName': 'James R Hein',
#  'email': 'jhein@usgs.gov',
#  'identifiers': [{'id': 1350, 'key': '0000-0002-5321-899X', 'type': 'ORCID'},
#   {'id': 1351, 'key': 'Q67225029', 'type': 'WikiData'}]}
# CPU times: user 255 ms, sys: 91.9 ms, total: 347 ms
# Wall time: 7.91 s

# %% [markdown]
# Because we are going to want to come back and reference the SB record in a minute when it comes to exploring individual properties on people, this helper function retrieves the URL that will let us get back into the ScienceBase Directory to see who we are talking about.

# %%
def sb_person_link_by_wd_id(people, wd_id):
    sb_link = next(
        (
            p["uri"] for p in people if next(
                (i for i in p["identifiers"] if i["key"] == wd_id), None) 
            is not None), 
        None)
    
    return sb_link

# %% [markdown]
# One of the functions we built into the WikiData class in this package will retrieve a given WikiData Item ("Q" identifier) and run some lookups to build out a reasonable document representation of the full record in WikiData. It runs through the statements/claims on a person and resolves property identifiers to provide a human-readable view of the properties of an item. The following codeblock demonstrates this for a slice of our list of USGS people with WikiData IDs. Each of the calles to wd_item() do take a little bit of time with this method based on resolving the properties.
#
# Note: There are likely better ways of handling this function fully with SPARQL that we'll figure out eventually.

# %%
# %%time
for person in people[20:22]:
    wd_id = next((i["key"] for i in person["identifiers"] if i["type"] == "WikiData"), None)
    display(wd.wd_item(wd_id, include_aliases=True))
# Out:
# {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/Q57414377.json',
#  'lastrevid': 1202763177,
#  'modified': '2020-06-09T06:30:58Z',
#  'label_en': 'Muruleedhara N Byappanahalli',
#  'description_en': 'researcher ORCID id 0000-0001-5376-597X',
#  'statements': [{'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P496.json',
#    'title': 'Property:P496',
#    'id': 'P496',
#    'label_en': 'ORCID iD',
#    'description_en': 'identifier for a person',
#    'formatter_url': 'https://orcid.org/$1',
#    'url': 'https://orcid.org/0000-0001-5376-597X',
#    'value': '0000-0001-5376-597X'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P31.json',
#    'title': 'Property:P31',
#    'id': 'P31',
#    'label_en': 'instance of',
#    'description_en': 'that class of which this subject is a particular example and member',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q5',
#    'value': 'human'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P1153.json',
#    'title': 'Property:P1153',
#    'id': 'P1153',
#    'label_en': 'Scopus author ID',
#    'description_en': 'identifier for an author assigned in Scopus bibliographic database',
#    'formatter_url': 'https://www.scopus.com/authid/detail.uri?authorId=$1',
#    'url': 'https://www.scopus.com/authid/detail.uri?authorId=6602901110',
#    'value': '6602901110'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P106.json',
#    'title': 'Property:P106',
#    'id': 'P106',
#    'label_en': 'occupation',
#    'description_en': 'occupation of a person; see also "field of work" (Property:P101), "position held" (Property:P39)',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q1650915',
#    'value': 'researcher'}]}
# {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/Q20675641.json',
#  'lastrevid': 1191864531,
#  'modified': '2020-05-27T21:58:07Z',
#  'label_en': 'Mark Petersen',
#  'description_en': 'seismologist',
#  'aliases': ['Mark D. Petersen',
#   'Mark Petersen',
#   'Mark D Petersen',
#   'M. D. Petersen',
#   'M.D. Petersen'],
#  'statements': [{'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P31.json',
#    'title': 'Property:P31',
#    'id': 'P31',
#    'label_en': 'instance of',
#    'description_en': 'that class of which this subject is a particular example and member',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q5',
#    'value': 'human'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P27.json',
#    'title': 'Property:P27',
#    'id': 'P27',
#    'label_en': 'country of citizenship',
#    'description_en': 'the object is a country that recognizes the subject as its citizen',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q30',
#    'value': 'United States of America'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P735.json',
#    'title': 'Property:P735',
#    'id': 'P735',
#    'label_en': 'given name',
#    'description_en': "first name or another given name of this person; values used with the property shouldn't link disambiguations nor family names.",
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q13610143',
#    'value': 'Mark'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P735.json',
#    'title': 'Property:P735',
#    'id': 'P735',
#    'label_en': 'given name',
#    'description_en': "first name or another given name of this person; values used with the property shouldn't link disambiguations nor family names.",
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q19803500',
#    'value': 'D.'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P21.json',
#    'title': 'Property:P21',
#    'id': 'P21',
#    'label_en': 'sex or gender',
#    'description_en': 'sex or gender identity: male (Q6581097), female (Q6581072), intersex (Q1097630), transgender female (Q1052281), transgender male (Q2449503). Animal: male organism (Q44148), female organism (Q43445). Groups of same gender use subclass of (P279)',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q6581097',
#    'value': 'male'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P19.json',
#    'title': 'Property:P19',
#    'id': 'P19',
#    'label_en': 'place of birth',
#    'description_en': 'most specific known (e.g. city instead of country, or hospital instead of city) birth location of a person, animal or fictional character',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q31058',
#    'value': 'Burlington'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P18.json',
#    'title': 'Property:P18',
#    'id': 'P18',
#    'label_en': 'image',
#    'description_en': 'image of relevant illustration of the subject; if available, use more specific properties (sample: coat of arms image, locator map, flag image, signature image, logo image, collage image); only images which exist on Wikimedia Commons are acceptable',
#    'formatter_url': 'https://commons.wikimedia.org/wiki/File:$1',
#    'url': 'https://commons.wikimedia.org/wiki/File:Mark badlands.jpg',
#    'value': 'Mark badlands.jpg'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P106.json',
#    'title': 'Property:P106',
#    'id': 'P106',
#    'label_en': 'occupation',
#    'description_en': 'occupation of a person; see also "field of work" (Property:P101), "position held" (Property:P39)',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q520549',
#    'value': 'geologist'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P106.json',
#    'title': 'Property:P106',
#    'id': 'P106',
#    'label_en': 'occupation',
#    'description_en': 'occupation of a person; see also "field of work" (Property:P101), "position held" (Property:P39)',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q12051314',
#    'value': 'seismologist'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P734.json',
#    'title': 'Property:P734',
#    'id': 'P734',
#    'label_en': 'family name',
#    'description_en': 'part of full name of person',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q27094683',
#    'value': 'Petersen'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P496.json',
#    'title': 'Property:P496',
#    'id': 'P496',
#    'label_en': 'ORCID iD',
#    'description_en': 'identifier for a person',
#    'formatter_url': 'https://orcid.org/$1',
#    'url': 'https://orcid.org/0000-0001-8542-3990',
#    'value': '0000-0001-8542-3990'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P1960.json',
#    'title': 'Property:P1960',
#    'id': 'P1960',
#    'label_en': 'Google Scholar author ID',
#    'description_en': 'identifier of a person, in the Google Scholar academic search service',
#    'formatter_url': 'https://scholar.google.com/citations?user=$1',
#    'url': 'https://scholar.google.com/citations?user=MFYshFUAAAAJ',
#    'value': 'MFYshFUAAAAJ'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P69.json',
#    'title': 'Property:P69',
#    'id': 'P69',
#    'label_en': 'educated at',
#    'description_en': 'educational institution attended by subject',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q49088',
#    'value': 'Columbia University'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P69.json',
#    'title': 'Property:P69',
#    'id': 'P69',
#    'label_en': 'educated at',
#    'description_en': 'educational institution attended by subject',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q332498',
#    'value': 'Brigham Young University'},
#   {'uri': 'https://www.wikidata.org/wiki/Special:EntityData/P108.json',
#    'title': 'Property:P108',
#    'id': 'P108',
#    'label_en': 'employer',
#    'description_en': 'person or organization for which the subject works or worked',
#    'formatter_url': None,
#    'url': 'https://www.wikidata.org/wiki/Special:EntityData/Q608427',
#    'value': 'United States Department of the Interior'}]}
# CPU times: user 651 ms, sys: 48.9 ms, total: 699 ms
# Wall time: 27.1 s

# %% [markdown]
# What we are really interested in through this immediate exercise is an examination of the breadth of properties in WikiData on USGS people. We want to understand what we can exploit from those claims made about our people and get some indication of where those statements have come from. The WikiData class contains another function that will take a list of specific item IDs and return all of the properties with English labels and values for those IDs. We can use this to comprehensively run through every USGS-affiliated WikiData ID and get a set of distinct properties to examine further.
#
# To be kind to the WikiData API and deal with limitations in how large a SPARQL query we can make, we batch process and slow down our requests in sending all 2K+ IDs.

# %%
# %%time
wd_ids = [next(i["key"] for i in p["identifiers"] if i["type"] == "WikiData") for p in people]

batch_size = 100
all_props = list()

for i in range(0, len(wd_ids), batch_size):
    this_run = wd_ids[i:i+batch_size]
    all_props.extend(wd.wd_item_properties(this_run, return_result="values"))
    time.sleep(0.2)
    
distinct_properties = list(set([p["property"] for p in all_props]))
display(distinct_properties)
# Out:
# ['Loop ID',
#  'on focus list of Wikimedia project',
#  'languages spoken, written or signed',
#  'member of',
#  'honorific suffix',
#  'FAST ID',
#  'Project Gutenberg author ID',
#  'Bibliothèque nationale de France ID',
#  'field of work',
#  'academic degree',
#  'LinkedIn personal profile ID',
#  'occupation',
#  'Google Scholar author ID',
#  'family name',
#  'nickname',
#  'ResearchGate contributions ID',
#  'NORAF ID',
#  'residence',
#  'DBLP ID',
#  'doctoral advisor',
#  'employer',
#  'Publons author ID',
#  'IdRef ID',
#  'botanist author abbreviation',
#  'official website',
#  'ISNI',
#  'educated at',
#  'ZooBank author ID',
#  'GND ID',
#  'ResearcherID',
#  'Libraries Australia ID',
#  'work location',
#  'MusicBrainz artist ID',
#  'IPNI author ID',
#  'NKCR AUT ID',
#  'different from',
#  'Mendeley person ID',
#  'Microsoft Academic ID',
#  'BHL creator ID',
#  'University of Barcelona authority ID',
#  'Biblioteca Nacional de España ID',
#  'Library of Congress authority ID',
#  'CiNii author ID (books)',
#  'given name',
#  'WorldCat Identities ID',
#  'National Library of Israel ID',
#  'honorific prefix',
#  'Freebase ID',
#  'NLA Trove ID',
#  'date of birth',
#  'notable work',
#  'Nationale Thesaurus voor Auteurs ID',
#  'Semantic Scholar author ID',
#  'GitHub username',
#  'VIAF ID',
#  'sex or gender',
#  'Dimensions author ID',
#  'RERO ID',
#  'award received',
#  'ORCID iD',
#  'CONOR ID',
#  'place of birth',
#  'country of citizenship',
#  'NUKAT ID',
#  'image',
#  'position held',
#  'described at URL',
#  'ResearchGate profile ID',
#  'Harvard Index of Botanists ID',
#  'Songkick artist ID',
#  'openMLOL author ID',
#  'Academic Tree ID',
#  'name in native language',
#  'affiliation',
#  'instance of',
#  'Scopus author ID']
# CPU times: user 560 ms, sys: 120 ms, total: 679 ms
# Wall time: 1min

# %% [markdown]
# Now that we have our suite of distinct properties, we can start looking for interesting tidbits of information, figure out where things came from, and think about what we might be able to do with the stuff we can get back through the USGS person to WikiData linkage. There seems to be some pretty interesting stuff in the collection of properties. The following codeblock can be tweaked to look at specific properties of interest. It takes a property name and provides a clickable set of URLs that will take you to the WikiData identity with that property and to the corresponding ScienceBase Directory item. At this point, we are just visually exploring the information to see what's happening with the data.

# %%
property_name = "sex or gender"
ids = list()
for record in [i for i in all_props if i["property"] == property_name]:
    ids.append(record["item_id"])
    print(f"https://www.wikidata.org/wiki/{record['item_id']}", sb_person_link_by_wd_id(people, record['item_id']))
    
print(len(list(set(ids))))
# Out:
# https://www.wikidata.org/wiki/Q20675641 https://www.sciencebase.gov/directory/person/8045
# https://www.wikidata.org/wiki/Q40203735 https://www.sciencebase.gov/directory/person/24855
# https://www.wikidata.org/wiki/Q42789708 https://www.sciencebase.gov/directory/person/948
# https://www.wikidata.org/wiki/Q42814439 https://www.sciencebase.gov/directory/person/6949
# https://www.wikidata.org/wiki/Q50597603 https://www.sciencebase.gov/directory/person/6551
# https://www.wikidata.org/wiki/Q54963192 https://www.sciencebase.gov/directory/person/2828
# https://www.wikidata.org/wiki/Q56948802 https://www.sciencebase.gov/directory/person/60525
# https://www.wikidata.org/wiki/Q57408099 https://www.sciencebase.gov/directory/person/15304
# https://www.wikidata.org/wiki/Q57408268 https://www.sciencebase.gov/directory/person/68963
# https://www.wikidata.org/wiki/Q57408275 https://www.sciencebase.gov/directory/person/58061
# https://www.wikidata.org/wiki/Q57408402 https://www.sciencebase.gov/directory/person/8217
# https://www.wikidata.org/wiki/Q57408499 https://www.sciencebase.gov/directory/person/1620
# https://www.wikidata.org/wiki/Q57408726 https://www.sciencebase.gov/directory/person/5500
# https://www.wikidata.org/wiki/Q57413581 https://www.sciencebase.gov/directory/person/5126
# https://www.wikidata.org/wiki/Q57413639 https://www.sciencebase.gov/directory/person/7826
# https://www.wikidata.org/wiki/Q57415245 https://www.sciencebase.gov/directory/person/5922
# https://www.wikidata.org/wiki/Q57431653 https://www.sciencebase.gov/directory/person/3849
# https://www.wikidata.org/wiki/Q57517444 https://www.sciencebase.gov/directory/person/1444
# https://www.wikidata.org/wiki/Q57733385 https://www.sciencebase.gov/directory/person/792
# https://www.wikidata.org/wiki/Q57821070 https://www.sciencebase.gov/directory/person/9095
# https://www.wikidata.org/wiki/Q58174520 https://www.sciencebase.gov/directory/person/6679
# https://www.wikidata.org/wiki/Q58309612 https://www.sciencebase.gov/directory/person/10927
# https://www.wikidata.org/wiki/Q59762433 https://www.sciencebase.gov/directory/person/4290
# https://www.wikidata.org/wiki/Q59762491 https://www.sciencebase.gov/directory/person/7420
# https://www.wikidata.org/wiki/Q59762543 https://www.sciencebase.gov/directory/person/8816
# https://www.wikidata.org/wiki/Q59762582 https://www.sciencebase.gov/directory/person/14747
# https://www.wikidata.org/wiki/Q59763068 https://www.sciencebase.gov/directory/person/9381
# https://www.wikidata.org/wiki/Q59763591 https://www.sciencebase.gov/directory/person/8091
# https://www.wikidata.org/wiki/Q59821808 https://www.sciencebase.gov/directory/person/12445
# https://www.wikidata.org/wiki/Q59831529 https://www.sciencebase.gov/directory/person/8121
# https://www.wikidata.org/wiki/Q59831781 https://www.sciencebase.gov/directory/person/14760
# https://www.wikidata.org/wiki/Q59832128 https://www.sciencebase.gov/directory/person/693
# https://www.wikidata.org/wiki/Q59832926 https://www.sciencebase.gov/directory/person/2157
# https://www.wikidata.org/wiki/Q59833012 https://www.sciencebase.gov/directory/person/14759
# https://www.wikidata.org/wiki/Q59833077 https://www.sciencebase.gov/directory/person/66361
# https://www.wikidata.org/wiki/Q59833171 https://www.sciencebase.gov/directory/person/58590
# https://www.wikidata.org/wiki/Q59834394 https://www.sciencebase.gov/directory/person/8107
# https://www.wikidata.org/wiki/Q60154676 https://www.sciencebase.gov/directory/person/24973
# https://www.wikidata.org/wiki/Q63859406 https://www.sciencebase.gov/directory/person/4677
# https://www.wikidata.org/wiki/Q66730355 https://www.sciencebase.gov/directory/person/7303
# https://www.wikidata.org/wiki/Q56339104 https://www.sciencebase.gov/directory/person/63438
# https://www.wikidata.org/wiki/Q57408656 https://www.sciencebase.gov/directory/person/72899
# https://www.wikidata.org/wiki/Q57413765 https://www.sciencebase.gov/directory/person/5419
# https://www.wikidata.org/wiki/Q57550573 https://www.sciencebase.gov/directory/person/1275
# https://www.wikidata.org/wiki/Q57818270 https://www.sciencebase.gov/directory/person/58199
# https://www.wikidata.org/wiki/Q57836676 https://www.sciencebase.gov/directory/person/1735
# https://www.wikidata.org/wiki/Q57836703 https://www.sciencebase.gov/directory/person/73233
# https://www.wikidata.org/wiki/Q57879630 https://www.sciencebase.gov/directory/person/4226
# https://www.wikidata.org/wiki/Q58065013 https://www.sciencebase.gov/directory/person/8494
# https://www.wikidata.org/wiki/Q58371324 https://www.sciencebase.gov/directory/person/3200
# https://www.wikidata.org/wiki/Q58470929 https://www.sciencebase.gov/directory/person/7638
# https://www.wikidata.org/wiki/Q59149954 https://www.sciencebase.gov/directory/person/72730
# https://www.wikidata.org/wiki/Q59384347 https://www.sciencebase.gov/directory/person/23106
# https://www.wikidata.org/wiki/Q59533129 https://www.sciencebase.gov/directory/person/356
# https://www.wikidata.org/wiki/Q59762394 https://www.sciencebase.gov/directory/person/11137
# https://www.wikidata.org/wiki/Q59763007 https://www.sciencebase.gov/directory/person/6919
# https://www.wikidata.org/wiki/Q59831683 https://www.sciencebase.gov/directory/person/9190
# https://www.wikidata.org/wiki/Q59832251 https://www.sciencebase.gov/directory/person/66623
# https://www.wikidata.org/wiki/Q59832358 https://www.sciencebase.gov/directory/person/67086
# https://www.wikidata.org/wiki/Q59832601 https://www.sciencebase.gov/directory/person/15362
# https://www.wikidata.org/wiki/Q59832791 https://www.sciencebase.gov/directory/person/5685
# https://www.wikidata.org/wiki/Q59832794 https://www.sciencebase.gov/directory/person/4575
# https://www.wikidata.org/wiki/Q59833191 https://www.sciencebase.gov/directory/person/73374
# https://www.wikidata.org/wiki/Q59833476 https://www.sciencebase.gov/directory/person/11584
# https://www.wikidata.org/wiki/Q59833888 https://www.sciencebase.gov/directory/person/72643
# https://www.wikidata.org/wiki/Q59834659 https://www.sciencebase.gov/directory/person/9906
# https://www.wikidata.org/wiki/Q59834679 https://www.sciencebase.gov/directory/person/66709
# https://www.wikidata.org/wiki/Q59834690 https://www.sciencebase.gov/directory/person/2236
# https://www.wikidata.org/wiki/Q64995439 https://www.sciencebase.gov/directory/person/77939
# https://www.wikidata.org/wiki/Q15460956 https://www.sciencebase.gov/directory/person/4746
# https://www.wikidata.org/wiki/Q21502710 https://www.sciencebase.gov/directory/person/1754
# https://www.wikidata.org/wiki/Q39451524 https://www.sciencebase.gov/directory/person/9153
# https://www.wikidata.org/wiki/Q41636555 https://www.sciencebase.gov/directory/person/7025
# https://www.wikidata.org/wiki/Q43198971 https://www.sciencebase.gov/directory/person/2136
# https://www.wikidata.org/wiki/Q55128642 https://www.sciencebase.gov/directory/person/10856
# https://www.wikidata.org/wiki/Q57408326 https://www.sciencebase.gov/directory/person/15483
# https://www.wikidata.org/wiki/Q57408395 https://www.sciencebase.gov/directory/person/3825
# https://www.wikidata.org/wiki/Q57408434 https://www.sciencebase.gov/directory/person/13525
# https://www.wikidata.org/wiki/Q57408545 https://www.sciencebase.gov/directory/person/13862
# https://www.wikidata.org/wiki/Q57408565 https://www.sciencebase.gov/directory/person/5863
# https://www.wikidata.org/wiki/Q57413595 https://www.sciencebase.gov/directory/person/1728
# https://www.wikidata.org/wiki/Q57414900 https://www.sciencebase.gov/directory/person/10063
# https://www.wikidata.org/wiki/Q57777392 https://www.sciencebase.gov/directory/person/71936
# https://www.wikidata.org/wiki/Q57818287 https://www.sciencebase.gov/directory/person/9379
# https://www.wikidata.org/wiki/Q57836672 https://www.sciencebase.gov/directory/person/24563
# https://www.wikidata.org/wiki/Q58338169 https://www.sciencebase.gov/directory/person/11266
# https://www.wikidata.org/wiki/Q59198106 https://www.sciencebase.gov/directory/person/3867
# https://www.wikidata.org/wiki/Q59695648 https://www.sciencebase.gov/directory/person/10474
# https://www.wikidata.org/wiki/Q59762379 https://www.sciencebase.gov/directory/person/1333
# https://www.wikidata.org/wiki/Q59762533 https://www.sciencebase.gov/directory/person/22692
# https://www.wikidata.org/wiki/Q59762721 https://www.sciencebase.gov/directory/person/72626
# https://www.wikidata.org/wiki/Q59762816 https://www.sciencebase.gov/directory/person/10445
# https://www.wikidata.org/wiki/Q59762928 https://www.sciencebase.gov/directory/person/10696
# https://www.wikidata.org/wiki/Q59763157 https://www.sciencebase.gov/directory/person/73767
# https://www.wikidata.org/wiki/Q59820560 https://www.sciencebase.gov/directory/person/3270
# https://www.wikidata.org/wiki/Q59831875 https://www.sciencebase.gov/directory/person/10612
# https://www.wikidata.org/wiki/Q59832164 https://www.sciencebase.gov/directory/person/7322
# https://www.wikidata.org/wiki/Q59832177 https://www.sciencebase.gov/directory/person/2448
# https://www.wikidata.org/wiki/Q59832293 https://www.sciencebase.gov/directory/person/6244
# https://www.wikidata.org/wiki/Q59832550 https://www.sciencebase.gov/directory/person/784
# https://www.wikidata.org/wiki/Q59832588 https://www.sciencebase.gov/directory/person/8632
# https://www.wikidata.org/wiki/Q59832648 https://www.sciencebase.gov/directory/person/6098
# https://www.wikidata.org/wiki/Q59832745 https://www.sciencebase.gov/directory/person/2619
# https://www.wikidata.org/wiki/Q59833038 https://www.sciencebase.gov/directory/person/12323
# https://www.wikidata.org/wiki/Q59833241 https://www.sciencebase.gov/directory/person/13939
# https://www.wikidata.org/wiki/Q59833426 https://www.sciencebase.gov/directory/person/12956
# https://www.wikidata.org/wiki/Q59833866 https://www.sciencebase.gov/directory/person/66314
# https://www.wikidata.org/wiki/Q59834510 https://www.sciencebase.gov/directory/person/1926
# https://www.wikidata.org/wiki/Q59834588 https://www.sciencebase.gov/directory/person/63601
# https://www.wikidata.org/wiki/Q59834718 https://www.sciencebase.gov/directory/person/64996
# https://www.wikidata.org/wiki/Q59834906 https://www.sciencebase.gov/directory/person/5836
# https://www.wikidata.org/wiki/Q59834926 https://www.sciencebase.gov/directory/person/7966
# https://www.wikidata.org/wiki/Q42833207 https://www.sciencebase.gov/directory/person/71356
# https://www.wikidata.org/wiki/Q43138884 https://www.sciencebase.gov/directory/person/895
# https://www.wikidata.org/wiki/Q44621754 https://www.sciencebase.gov/directory/person/1349
# https://www.wikidata.org/wiki/Q45400085 https://www.sciencebase.gov/directory/person/11332
# https://www.wikidata.org/wiki/Q46227952 https://www.sciencebase.gov/directory/person/10684
# https://www.wikidata.org/wiki/Q47555160 https://www.sciencebase.gov/directory/person/67886
# https://www.wikidata.org/wiki/Q56339119 https://www.sciencebase.gov/directory/person/63375
# https://www.wikidata.org/wiki/Q56515954 https://www.sciencebase.gov/directory/person/8129
# https://www.wikidata.org/wiki/Q56803969 https://www.sciencebase.gov/directory/person/10893
# https://www.wikidata.org/wiki/Q57408239 https://www.sciencebase.gov/directory/person/9169
# https://www.wikidata.org/wiki/Q57408374 https://www.sciencebase.gov/directory/person/1392
# https://www.wikidata.org/wiki/Q57412227 https://www.sciencebase.gov/directory/person/66431
# https://www.wikidata.org/wiki/Q57413525 https://www.sciencebase.gov/directory/person/2537
# https://www.wikidata.org/wiki/Q57414786 https://www.sciencebase.gov/directory/person/9298
# https://www.wikidata.org/wiki/Q57414880 https://www.sciencebase.gov/directory/person/9685
# https://www.wikidata.org/wiki/Q57415305 https://www.sciencebase.gov/directory/person/1692
# https://www.wikidata.org/wiki/Q57733011 https://www.sciencebase.gov/directory/person/7802
# https://www.wikidata.org/wiki/Q57912491 https://www.sciencebase.gov/directory/person/10660
# https://www.wikidata.org/wiki/Q58006062 https://www.sciencebase.gov/directory/person/11047
# https://www.wikidata.org/wiki/Q58099663 https://www.sciencebase.gov/directory/person/72963
# https://www.wikidata.org/wiki/Q58149971 https://www.sciencebase.gov/directory/person/2692
# https://www.wikidata.org/wiki/Q58359571 https://www.sciencebase.gov/directory/person/5866
# https://www.wikidata.org/wiki/Q58371330 https://www.sciencebase.gov/directory/person/58309
# https://www.wikidata.org/wiki/Q58418174 https://www.sciencebase.gov/directory/person/73285
# https://www.wikidata.org/wiki/Q59676610 https://www.sciencebase.gov/directory/person/58642
# https://www.wikidata.org/wiki/Q59762224 https://www.sciencebase.gov/directory/person/11191
# https://www.wikidata.org/wiki/Q59762401 https://www.sciencebase.gov/directory/person/11310
# https://www.wikidata.org/wiki/Q59762537 https://www.sciencebase.gov/directory/person/5120
# https://www.wikidata.org/wiki/Q59762765 https://www.sciencebase.gov/directory/person/4702
# https://www.wikidata.org/wiki/Q59816908 https://www.sciencebase.gov/directory/person/452
# https://www.wikidata.org/wiki/Q59831774 https://www.sciencebase.gov/directory/person/8034
# https://www.wikidata.org/wiki/Q59831974 https://www.sciencebase.gov/directory/person/3978
# https://www.wikidata.org/wiki/Q59831988 https://www.sciencebase.gov/directory/person/9009
# https://www.wikidata.org/wiki/Q59832205 https://www.sciencebase.gov/directory/person/11304
# https://www.wikidata.org/wiki/Q59832333 https://www.sciencebase.gov/directory/person/10639
# https://www.wikidata.org/wiki/Q59832521 https://www.sciencebase.gov/directory/person/5756
# https://www.wikidata.org/wiki/Q59832561 https://www.sciencebase.gov/directory/person/5138
# https://www.wikidata.org/wiki/Q59832650 https://www.sciencebase.gov/directory/person/3697
# https://www.wikidata.org/wiki/Q59832862 https://www.sciencebase.gov/directory/person/3113
# https://www.wikidata.org/wiki/Q59833861 https://www.sciencebase.gov/directory/person/8779
# https://www.wikidata.org/wiki/Q59834852 https://www.sciencebase.gov/directory/person/9803
# https://www.wikidata.org/wiki/Q59834921 https://www.sciencebase.gov/directory/person/3059
# https://www.wikidata.org/wiki/Q59835038 https://www.sciencebase.gov/directory/person/68179
# https://www.wikidata.org/wiki/Q556752 https://www.sciencebase.gov/directory/person/6847
# https://www.wikidata.org/wiki/Q14949164 https://www.sciencebase.gov/directory/person/8388
# https://www.wikidata.org/wiki/Q42871182 https://www.sciencebase.gov/directory/person/7448
# https://www.wikidata.org/wiki/Q51566560 https://www.sciencebase.gov/directory/person/2443
# https://www.wikidata.org/wiki/Q55112211 https://www.sciencebase.gov/directory/person/6346
# https://www.wikidata.org/wiki/Q55763426 https://www.sciencebase.gov/directory/person/9422
# https://www.wikidata.org/wiki/Q57204947 https://www.sciencebase.gov/directory/person/68956
# https://www.wikidata.org/wiki/Q57412779 https://www.sciencebase.gov/directory/person/599
# https://www.wikidata.org/wiki/Q57414287 https://www.sciencebase.gov/directory/person/64800
# https://www.wikidata.org/wiki/Q57414964 https://www.sciencebase.gov/directory/person/66617
# https://www.wikidata.org/wiki/Q57726555 https://www.sciencebase.gov/directory/person/2292
# https://www.wikidata.org/wiki/Q57913558 https://www.sciencebase.gov/directory/person/8916
# https://www.wikidata.org/wiki/Q57916956 https://www.sciencebase.gov/directory/person/71916
# https://www.wikidata.org/wiki/Q58423759 https://www.sciencebase.gov/directory/person/23462
# https://www.wikidata.org/wiki/Q59762369 https://www.sciencebase.gov/directory/person/2885
# https://www.wikidata.org/wiki/Q59762529 https://www.sciencebase.gov/directory/person/10190
# https://www.wikidata.org/wiki/Q59831914 https://www.sciencebase.gov/directory/person/11854
# https://www.wikidata.org/wiki/Q59832016 https://www.sciencebase.gov/directory/person/8229
# https://www.wikidata.org/wiki/Q59832042 https://www.sciencebase.gov/directory/person/6652
# https://www.wikidata.org/wiki/Q59832463 https://www.sciencebase.gov/directory/person/1181
# https://www.wikidata.org/wiki/Q59832512 https://www.sciencebase.gov/directory/person/6194
# https://www.wikidata.org/wiki/Q59832847 https://www.sciencebase.gov/directory/person/8277
# https://www.wikidata.org/wiki/Q59833040 https://www.sciencebase.gov/directory/person/22845
# https://www.wikidata.org/wiki/Q59833156 https://www.sciencebase.gov/directory/person/2596
# https://www.wikidata.org/wiki/Q59833495 https://www.sciencebase.gov/directory/person/1691
# https://www.wikidata.org/wiki/Q59834830 https://www.sciencebase.gov/directory/person/70305
# https://www.wikidata.org/wiki/Q59834952 https://www.sciencebase.gov/directory/person/69018
# https://www.wikidata.org/wiki/Q59835058 https://www.sciencebase.gov/directory/person/9358
# https://www.wikidata.org/wiki/Q66730358 https://www.sciencebase.gov/directory/person/488
# https://www.wikidata.org/wiki/Q39694568 https://www.sciencebase.gov/directory/person/4171
# https://www.wikidata.org/wiki/Q42181691 https://www.sciencebase.gov/directory/person/4106
# https://www.wikidata.org/wiki/Q42830479 https://www.sciencebase.gov/directory/person/2784
# https://www.wikidata.org/wiki/Q43071171 https://www.sciencebase.gov/directory/person/8604
# https://www.wikidata.org/wiki/Q44044298 https://www.sciencebase.gov/directory/person/5692
# https://www.wikidata.org/wiki/Q47330042 https://www.sciencebase.gov/directory/person/8792
# https://www.wikidata.org/wiki/Q5081804 https://www.sciencebase.gov/directory/person/403
# https://www.wikidata.org/wiki/Q55188944 https://www.sciencebase.gov/directory/person/2558
# https://www.wikidata.org/wiki/Q56332291 https://www.sciencebase.gov/directory/person/670
# https://www.wikidata.org/wiki/Q56420729 https://www.sciencebase.gov/directory/person/14017
# https://www.wikidata.org/wiki/Q56480253 https://www.sciencebase.gov/directory/person/66155
# https://www.wikidata.org/wiki/Q56678871 https://www.sciencebase.gov/directory/person/1903
# https://www.wikidata.org/wiki/Q57408366 https://www.sciencebase.gov/directory/person/9037
# https://www.wikidata.org/wiki/Q57777369 https://www.sciencebase.gov/directory/person/8070
# https://www.wikidata.org/wiki/Q57777417 https://www.sciencebase.gov/directory/person/1201
# https://www.wikidata.org/wiki/Q57844646 https://www.sciencebase.gov/directory/person/11534
# https://www.wikidata.org/wiki/Q57936257 https://www.sciencebase.gov/directory/person/8859
# https://www.wikidata.org/wiki/Q58051262 https://www.sciencebase.gov/directory/person/8312
# https://www.wikidata.org/wiki/Q58173658 https://www.sciencebase.gov/directory/person/7543
# https://www.wikidata.org/wiki/Q58207242 https://www.sciencebase.gov/directory/person/2205
# https://www.wikidata.org/wiki/Q58371326 https://www.sciencebase.gov/directory/person/3595
# https://www.wikidata.org/wiki/Q58435775 https://www.sciencebase.gov/directory/person/4075
# https://www.wikidata.org/wiki/Q59762553 https://www.sciencebase.gov/directory/person/24038
# https://www.wikidata.org/wiki/Q59762652 https://www.sciencebase.gov/directory/person/65530
# https://www.wikidata.org/wiki/Q59832263 https://www.sciencebase.gov/directory/person/22645
# https://www.wikidata.org/wiki/Q59832315 https://www.sciencebase.gov/directory/person/807
# https://www.wikidata.org/wiki/Q59832339 https://www.sciencebase.gov/directory/person/10966
# https://www.wikidata.org/wiki/Q59832348 https://www.sciencebase.gov/directory/person/8762
# https://www.wikidata.org/wiki/Q59832424 https://www.sciencebase.gov/directory/person/7267
# https://www.wikidata.org/wiki/Q59832546 https://www.sciencebase.gov/directory/person/9957
# https://www.wikidata.org/wiki/Q59832548 https://www.sciencebase.gov/directory/person/5411
# https://www.wikidata.org/wiki/Q59833024 https://www.sciencebase.gov/directory/person/9711
# https://www.wikidata.org/wiki/Q59833113 https://www.sciencebase.gov/directory/person/3554
# https://www.wikidata.org/wiki/Q59833468 https://www.sciencebase.gov/directory/person/7792
# https://www.wikidata.org/wiki/Q59833660 https://www.sciencebase.gov/directory/person/5680
# https://www.wikidata.org/wiki/Q59833988 https://www.sciencebase.gov/directory/person/5403
# https://www.wikidata.org/wiki/Q59834026 https://www.sciencebase.gov/directory/person/1150
# https://www.wikidata.org/wiki/Q59835047 https://www.sciencebase.gov/directory/person/3752
# https://www.wikidata.org/wiki/Q42260508 https://www.sciencebase.gov/directory/person/4946
# https://www.wikidata.org/wiki/Q44891806 https://www.sciencebase.gov/directory/person/8581
# https://www.wikidata.org/wiki/Q46733032 https://www.sciencebase.gov/directory/person/11566
# https://www.wikidata.org/wiki/Q47340916 https://www.sciencebase.gov/directory/person/6420
# https://www.wikidata.org/wiki/Q55487431 https://www.sciencebase.gov/directory/person/60653
# https://www.wikidata.org/wiki/Q56333886 https://www.sciencebase.gov/directory/person/59573
# https://www.wikidata.org/wiki/Q56547200 https://www.sciencebase.gov/directory/person/68217
# https://www.wikidata.org/wiki/Q57408380 https://www.sciencebase.gov/directory/person/4019
# https://www.wikidata.org/wiki/Q57408662 https://www.sciencebase.gov/directory/person/60521
# https://www.wikidata.org/wiki/Q57408670 https://www.sciencebase.gov/directory/person/65309
# https://www.wikidata.org/wiki/Q57414368 https://www.sciencebase.gov/directory/person/2230
# https://www.wikidata.org/wiki/Q57419817 https://www.sciencebase.gov/directory/person/6758
# https://www.wikidata.org/wiki/Q57516224 https://www.sciencebase.gov/directory/person/11203
# https://www.wikidata.org/wiki/Q57726562 https://www.sciencebase.gov/directory/person/9305
# https://www.wikidata.org/wiki/Q57983623 https://www.sciencebase.gov/directory/person/7304
# https://www.wikidata.org/wiki/Q58148032 https://www.sciencebase.gov/directory/person/9308
# https://www.wikidata.org/wiki/Q58307933 https://www.sciencebase.gov/directory/person/8238
# https://www.wikidata.org/wiki/Q58346225 https://www.sciencebase.gov/directory/person/66515
# https://www.wikidata.org/wiki/Q58418057 https://www.sciencebase.gov/directory/person/8143
# https://www.wikidata.org/wiki/Q58923902 https://www.sciencebase.gov/directory/person/521
# https://www.wikidata.org/wiki/Q59749603 https://www.sciencebase.gov/directory/person/62377
# https://www.wikidata.org/wiki/Q59762292 https://www.sciencebase.gov/directory/person/73394
# https://www.wikidata.org/wiki/Q59762610 https://www.sciencebase.gov/directory/person/4765
# https://www.wikidata.org/wiki/Q59762999 https://www.sciencebase.gov/directory/person/12114
# https://www.wikidata.org/wiki/Q59763044 https://www.sciencebase.gov/directory/person/437
# https://www.wikidata.org/wiki/Q59807717 https://www.sciencebase.gov/directory/person/5094
# https://www.wikidata.org/wiki/Q59832383 https://www.sciencebase.gov/directory/person/7402
# https://www.wikidata.org/wiki/Q59833194 https://www.sciencebase.gov/directory/person/7550
# https://www.wikidata.org/wiki/Q59833507 https://www.sciencebase.gov/directory/person/13489
# https://www.wikidata.org/wiki/Q59833796 https://www.sciencebase.gov/directory/person/196
# https://www.wikidata.org/wiki/Q64915190 https://www.sciencebase.gov/directory/person/6517
# https://www.wikidata.org/wiki/Q66472641 https://www.sciencebase.gov/directory/person/5660
# https://www.wikidata.org/wiki/Q43095026 https://www.sciencebase.gov/directory/person/746
# https://www.wikidata.org/wiki/Q46227932 https://www.sciencebase.gov/directory/person/4778
# https://www.wikidata.org/wiki/Q47306471 https://www.sciencebase.gov/directory/person/24874
# https://www.wikidata.org/wiki/Q51157382 https://www.sciencebase.gov/directory/person/19562
# https://www.wikidata.org/wiki/Q54858751 https://www.sciencebase.gov/directory/person/66875
# https://www.wikidata.org/wiki/Q56462578 https://www.sciencebase.gov/directory/person/4992
# https://www.wikidata.org/wiki/Q56885989 https://www.sciencebase.gov/directory/person/24226
# https://www.wikidata.org/wiki/Q57078378 https://www.sciencebase.gov/directory/person/59843
# https://www.wikidata.org/wiki/Q57408090 https://www.sciencebase.gov/directory/person/71436
# https://www.wikidata.org/wiki/Q57408610 https://www.sciencebase.gov/directory/person/2900
# https://www.wikidata.org/wiki/Q57408715 https://www.sciencebase.gov/directory/person/71260
# https://www.wikidata.org/wiki/Q57413982 https://www.sciencebase.gov/directory/person/6846
# https://www.wikidata.org/wiki/Q57415694 https://www.sciencebase.gov/directory/person/13502
# https://www.wikidata.org/wiki/Q57491678 https://www.sciencebase.gov/directory/person/4416
# https://www.wikidata.org/wiki/Q57732991 https://www.sciencebase.gov/directory/person/4627
# https://www.wikidata.org/wiki/Q57818291 https://www.sciencebase.gov/directory/person/6435
# https://www.wikidata.org/wiki/Q57837305 https://www.sciencebase.gov/directory/person/4069
# https://www.wikidata.org/wiki/Q58150487 https://www.sciencebase.gov/directory/person/9146
# https://www.wikidata.org/wiki/Q58193304 https://www.sciencebase.gov/directory/person/2512
# https://www.wikidata.org/wiki/Q58338141 https://www.sciencebase.gov/directory/person/11000
# https://www.wikidata.org/wiki/Q58413538 https://www.sciencebase.gov/directory/person/6907
# https://www.wikidata.org/wiki/Q59689902 https://www.sciencebase.gov/directory/person/71160
# https://www.wikidata.org/wiki/Q59762645 https://www.sciencebase.gov/directory/person/71690
# https://www.wikidata.org/wiki/Q59762735 https://www.sciencebase.gov/directory/person/72244
# https://www.wikidata.org/wiki/Q59822160 https://www.sciencebase.gov/directory/person/5631
# https://www.wikidata.org/wiki/Q59831656 https://www.sciencebase.gov/directory/person/11536
# https://www.wikidata.org/wiki/Q59831960 https://www.sciencebase.gov/directory/person/9631
# https://www.wikidata.org/wiki/Q59832320 https://www.sciencebase.gov/directory/person/10467
# https://www.wikidata.org/wiki/Q59832532 https://www.sciencebase.gov/directory/person/4016
# https://www.wikidata.org/wiki/Q59832692 https://www.sciencebase.gov/directory/person/6578
# https://www.wikidata.org/wiki/Q59832825 https://www.sciencebase.gov/directory/person/12312
# https://www.wikidata.org/wiki/Q59832914 https://www.sciencebase.gov/directory/person/75390
# https://www.wikidata.org/wiki/Q59833083 https://www.sciencebase.gov/directory/person/24227
# https://www.wikidata.org/wiki/Q59833624 https://www.sciencebase.gov/directory/person/59217
# https://www.wikidata.org/wiki/Q59833833 https://www.sciencebase.gov/directory/person/62235
# https://www.wikidata.org/wiki/Q59833839 https://www.sciencebase.gov/directory/person/70188
# https://www.wikidata.org/wiki/Q59834100 https://www.sciencebase.gov/directory/person/10343
# https://www.wikidata.org/wiki/Q59834144 https://www.sciencebase.gov/directory/person/4658
# https://www.wikidata.org/wiki/Q59835002 https://www.sciencebase.gov/directory/person/13371
# https://www.wikidata.org/wiki/Q59835078 https://www.sciencebase.gov/directory/person/706
# https://www.wikidata.org/wiki/Q59835100 https://www.sciencebase.gov/directory/person/5687
# https://www.wikidata.org/wiki/Q59870812 https://www.sciencebase.gov/directory/person/65382
# https://www.wikidata.org/wiki/Q60228308 https://www.sciencebase.gov/directory/person/1284
# https://www.wikidata.org/wiki/Q70348318 https://www.sciencebase.gov/directory/person/3286
# https://www.wikidata.org/wiki/Q54994335 https://www.sciencebase.gov/directory/person/3417
# https://www.wikidata.org/wiki/Q56809282 https://www.sciencebase.gov/directory/person/79044
# https://www.wikidata.org/wiki/Q56999305 https://www.sciencebase.gov/directory/person/69577
# https://www.wikidata.org/wiki/Q57195859 https://www.sciencebase.gov/directory/person/6771
# https://www.wikidata.org/wiki/Q57408409 https://www.sciencebase.gov/directory/person/490
# https://www.wikidata.org/wiki/Q57414861 https://www.sciencebase.gov/directory/person/18352
# https://www.wikidata.org/wiki/Q57543232 https://www.sciencebase.gov/directory/person/62231
# https://www.wikidata.org/wiki/Q57720848 https://www.sciencebase.gov/directory/person/10363
# https://www.wikidata.org/wiki/Q57729525 https://www.sciencebase.gov/directory/person/7005
# https://www.wikidata.org/wiki/Q57734808 https://www.sciencebase.gov/directory/person/10573
# https://www.wikidata.org/wiki/Q57734821 https://www.sciencebase.gov/directory/person/8193
# https://www.wikidata.org/wiki/Q58876101 https://www.sciencebase.gov/directory/person/9549
# https://www.wikidata.org/wiki/Q59698331 https://www.sciencebase.gov/directory/person/7944
# https://www.wikidata.org/wiki/Q59750861 https://www.sciencebase.gov/directory/person/7870
# https://www.wikidata.org/wiki/Q59762376 https://www.sciencebase.gov/directory/person/5752
# https://www.wikidata.org/wiki/Q59816887 https://www.sciencebase.gov/directory/person/5024
# https://www.wikidata.org/wiki/Q59826927 https://www.sciencebase.gov/directory/person/24573
# https://www.wikidata.org/wiki/Q59831817 https://www.sciencebase.gov/directory/person/7978
# https://www.wikidata.org/wiki/Q59831861 https://www.sciencebase.gov/directory/person/5453
# https://www.wikidata.org/wiki/Q59831935 https://www.sciencebase.gov/directory/person/3285
# https://www.wikidata.org/wiki/Q59832277 https://www.sciencebase.gov/directory/person/11406
# https://www.wikidata.org/wiki/Q59832403 https://www.sciencebase.gov/directory/person/8926
# https://www.wikidata.org/wiki/Q59832611 https://www.sciencebase.gov/directory/person/2907
# https://www.wikidata.org/wiki/Q59832688 https://www.sciencebase.gov/directory/person/2643
# https://www.wikidata.org/wiki/Q59832784 https://www.sciencebase.gov/directory/person/8575
# https://www.wikidata.org/wiki/Q59833067 https://www.sciencebase.gov/directory/person/11022
# https://www.wikidata.org/wiki/Q59833070 https://www.sciencebase.gov/directory/person/2492
# https://www.wikidata.org/wiki/Q59833473 https://www.sciencebase.gov/directory/person/70516
# https://www.wikidata.org/wiki/Q59833921 https://www.sciencebase.gov/directory/person/65333
# https://www.wikidata.org/wiki/Q59834008 https://www.sciencebase.gov/directory/person/7316
# https://www.wikidata.org/wiki/Q59834479 https://www.sciencebase.gov/directory/person/63810
# https://www.wikidata.org/wiki/Q61941643 https://www.sciencebase.gov/directory/person/8021
# https://www.wikidata.org/wiki/Q93121619 https://www.sciencebase.gov/directory/person/11116
# https://www.wikidata.org/wiki/Q21339166 https://www.sciencebase.gov/directory/person/11434
# https://www.wikidata.org/wiki/Q21390710 https://www.sciencebase.gov/directory/person/6271
# https://www.wikidata.org/wiki/Q41954420 https://www.sciencebase.gov/directory/person/13698
# https://www.wikidata.org/wiki/Q55209035 https://www.sciencebase.gov/directory/person/5375
# https://www.wikidata.org/wiki/Q55445986 https://www.sciencebase.gov/directory/person/7353
# https://www.wikidata.org/wiki/Q56100059 https://www.sciencebase.gov/directory/person/9522
# https://www.wikidata.org/wiki/Q56802228 https://www.sciencebase.gov/directory/person/8917
# https://www.wikidata.org/wiki/Q57209485 https://www.sciencebase.gov/directory/person/66129
# https://www.wikidata.org/wiki/Q57408490 https://www.sciencebase.gov/directory/person/13565
# https://www.wikidata.org/wiki/Q57408502 https://www.sciencebase.gov/directory/person/3839
# https://www.wikidata.org/wiki/Q57414741 https://www.sciencebase.gov/directory/person/8833
# https://www.wikidata.org/wiki/Q57734819 https://www.sciencebase.gov/directory/person/905
# https://www.wikidata.org/wiki/Q57777385 https://www.sciencebase.gov/directory/person/11644
# https://www.wikidata.org/wiki/Q57913473 https://www.sciencebase.gov/directory/person/24149
# https://www.wikidata.org/wiki/Q58193270 https://www.sciencebase.gov/directory/person/13532
# https://www.wikidata.org/wiki/Q58336325 https://www.sciencebase.gov/directory/person/7252
# https://www.wikidata.org/wiki/Q59556961 https://www.sciencebase.gov/directory/person/7377
# https://www.wikidata.org/wiki/Q59702616 https://www.sciencebase.gov/directory/person/66198
# https://www.wikidata.org/wiki/Q59707935 https://www.sciencebase.gov/directory/person/2638
# https://www.wikidata.org/wiki/Q59762364 https://www.sciencebase.gov/directory/person/2568
# https://www.wikidata.org/wiki/Q59762679 https://www.sciencebase.gov/directory/person/5
# https://www.wikidata.org/wiki/Q59832191 https://www.sciencebase.gov/directory/person/9304
# https://www.wikidata.org/wiki/Q59833124 https://www.sciencebase.gov/directory/person/14385
# https://www.wikidata.org/wiki/Q59833394 https://www.sciencebase.gov/directory/person/4598
# https://www.wikidata.org/wiki/Q59833519 https://www.sciencebase.gov/directory/person/1957
# https://www.wikidata.org/wiki/Q59833944 https://www.sciencebase.gov/directory/person/10044
# https://www.wikidata.org/wiki/Q59833991 https://www.sciencebase.gov/directory/person/6642
# https://www.wikidata.org/wiki/Q59834007 https://www.sciencebase.gov/directory/person/66945
# https://www.wikidata.org/wiki/Q59834641 https://www.sciencebase.gov/directory/person/3576
# https://www.wikidata.org/wiki/Q59835069 https://www.sciencebase.gov/directory/person/5320
# https://www.wikidata.org/wiki/Q60390660 https://www.sciencebase.gov/directory/person/78263
# https://www.wikidata.org/wiki/Q64437837 https://www.sciencebase.gov/directory/person/8727
# https://www.wikidata.org/wiki/Q42032714 https://www.sciencebase.gov/directory/person/6256
# https://www.wikidata.org/wiki/Q42370282 https://www.sciencebase.gov/directory/person/78033
# https://www.wikidata.org/wiki/Q43173850 https://www.sciencebase.gov/directory/person/8393
# https://www.wikidata.org/wiki/Q43187713 https://www.sciencebase.gov/directory/person/62957
# https://www.wikidata.org/wiki/Q43539662 https://www.sciencebase.gov/directory/person/2802
# https://www.wikidata.org/wiki/Q50646609 https://www.sciencebase.gov/directory/person/168
# https://www.wikidata.org/wiki/Q56975732 https://www.sciencebase.gov/directory/person/5308
# https://www.wikidata.org/wiki/Q56994367 https://www.sciencebase.gov/directory/person/65986
# https://www.wikidata.org/wiki/Q57408636 https://www.sciencebase.gov/directory/person/15701
# https://www.wikidata.org/wiki/Q57445137 https://www.sciencebase.gov/directory/person/2538
# https://www.wikidata.org/wiki/Q57777395 https://www.sciencebase.gov/directory/person/10852
# https://www.wikidata.org/wiki/Q57912481 https://www.sciencebase.gov/directory/person/1634
# https://www.wikidata.org/wiki/Q58331805 https://www.sciencebase.gov/directory/person/11313
# https://www.wikidata.org/wiki/Q58338143 https://www.sciencebase.gov/directory/person/10200
# https://www.wikidata.org/wiki/Q58422367 https://www.sciencebase.gov/directory/person/16184
# https://www.wikidata.org/wiki/Q59610453 https://www.sciencebase.gov/directory/person/2599
# https://www.wikidata.org/wiki/Q59684741 https://www.sciencebase.gov/directory/person/7797
# https://www.wikidata.org/wiki/Q59749245 https://www.sciencebase.gov/directory/person/9152
# https://www.wikidata.org/wiki/Q59762396 https://www.sciencebase.gov/directory/person/22997
# https://www.wikidata.org/wiki/Q59762677 https://www.sciencebase.gov/directory/person/955
# https://www.wikidata.org/wiki/Q59763200 https://www.sciencebase.gov/directory/person/73248
# https://www.wikidata.org/wiki/Q59826923 https://www.sciencebase.gov/directory/person/2556
# https://www.wikidata.org/wiki/Q59832502 https://www.sciencebase.gov/directory/person/2935
# https://www.wikidata.org/wiki/Q59832916 https://www.sciencebase.gov/directory/person/7498
# https://www.wikidata.org/wiki/Q59833026 https://www.sciencebase.gov/directory/person/64589
# https://www.wikidata.org/wiki/Q59833126 https://www.sciencebase.gov/directory/person/15316
# https://www.wikidata.org/wiki/Q59833178 https://www.sciencebase.gov/directory/person/4076
# https://www.wikidata.org/wiki/Q59833786 https://www.sciencebase.gov/directory/person/73249
# https://www.wikidata.org/wiki/Q59833808 https://www.sciencebase.gov/directory/person/1782
# https://www.wikidata.org/wiki/Q59834789 https://www.sciencebase.gov/directory/person/72961
# https://www.wikidata.org/wiki/Q62129275 https://www.sciencebase.gov/directory/person/2894
# https://www.wikidata.org/wiki/Q39521548 https://www.sciencebase.gov/directory/person/5869
# https://www.wikidata.org/wiki/Q39851977 https://www.sciencebase.gov/directory/person/9123
# https://www.wikidata.org/wiki/Q41463916 https://www.sciencebase.gov/directory/person/4697
# https://www.wikidata.org/wiki/Q46941727 https://www.sciencebase.gov/directory/person/7506
# https://www.wikidata.org/wiki/Q56208271 https://www.sciencebase.gov/directory/person/9652
# https://www.wikidata.org/wiki/Q56396134 https://www.sciencebase.gov/directory/person/5901
# https://www.wikidata.org/wiki/Q56558524 https://www.sciencebase.gov/directory/person/69989
# https://www.wikidata.org/wiki/Q57075145 https://www.sciencebase.gov/directory/person/5638
# https://www.wikidata.org/wiki/Q57408162 https://www.sciencebase.gov/directory/person/1805
# https://www.wikidata.org/wiki/Q57408467 https://www.sciencebase.gov/directory/person/69488
# https://www.wikidata.org/wiki/Q57408539 https://www.sciencebase.gov/directory/person/10633
# https://www.wikidata.org/wiki/Q57408624 https://www.sciencebase.gov/directory/person/3517
# https://www.wikidata.org/wiki/Q57413938 https://www.sciencebase.gov/directory/person/22708
# https://www.wikidata.org/wiki/Q57415243 https://www.sciencebase.gov/directory/person/6587
# https://www.wikidata.org/wiki/Q57422414 https://www.sciencebase.gov/directory/person/59397
# https://www.wikidata.org/wiki/Q57836694 https://www.sciencebase.gov/directory/person/1475
# https://www.wikidata.org/wiki/Q57845110 https://www.sciencebase.gov/directory/person/65215
# https://www.wikidata.org/wiki/Q57879016 https://www.sciencebase.gov/directory/person/69429
# https://www.wikidata.org/wiki/Q58218561 https://www.sciencebase.gov/directory/person/13397
# https://www.wikidata.org/wiki/Q58338148 https://www.sciencebase.gov/directory/person/10651
# https://www.wikidata.org/wiki/Q58423173 https://www.sciencebase.gov/directory/person/15751
# https://www.wikidata.org/wiki/Q58424472 https://www.sciencebase.gov/directory/person/3653
# https://www.wikidata.org/wiki/Q59749089 https://www.sciencebase.gov/directory/person/6582
# https://www.wikidata.org/wiki/Q59762367 https://www.sciencebase.gov/directory/person/4840
# https://www.wikidata.org/wiki/Q59762390 https://www.sciencebase.gov/directory/person/11564
# https://www.wikidata.org/wiki/Q59822123 https://www.sciencebase.gov/directory/person/69343
# https://www.wikidata.org/wiki/Q59831902 https://www.sciencebase.gov/directory/person/59498
# https://www.wikidata.org/wiki/Q59832023 https://www.sciencebase.gov/directory/person/3541
# https://www.wikidata.org/wiki/Q59832218 https://www.sciencebase.gov/directory/person/11770
# https://www.wikidata.org/wiki/Q59832815 https://www.sciencebase.gov/directory/person/4441
# https://www.wikidata.org/wiki/Q59833063 https://www.sciencebase.gov/directory/person/6406
# https://www.wikidata.org/wiki/Q59833146 https://www.sciencebase.gov/directory/person/14567
# https://www.wikidata.org/wiki/Q59833168 https://www.sciencebase.gov/directory/person/224
# https://www.wikidata.org/wiki/Q59833650 https://www.sciencebase.gov/directory/person/70211
# https://www.wikidata.org/wiki/Q59834035 https://www.sciencebase.gov/directory/person/69799
# https://www.wikidata.org/wiki/Q59834900 https://www.sciencebase.gov/directory/person/5718
# https://www.wikidata.org/wiki/Q59835107 https://www.sciencebase.gov/directory/person/10285
# https://www.wikidata.org/wiki/Q6175888 https://www.sciencebase.gov/directory/person/11509
# https://www.wikidata.org/wiki/Q66763745 https://www.sciencebase.gov/directory/person/4611
# https://www.wikidata.org/wiki/Q38359442 https://www.sciencebase.gov/directory/person/60839
# https://www.wikidata.org/wiki/Q42175561 https://www.sciencebase.gov/directory/person/66295
# https://www.wikidata.org/wiki/Q42717914 https://www.sciencebase.gov/directory/person/2306
# https://www.wikidata.org/wiki/Q42848465 https://www.sciencebase.gov/directory/person/1391
# https://www.wikidata.org/wiki/Q46781491 https://www.sciencebase.gov/directory/person/24386
# https://www.wikidata.org/wiki/Q56417268 https://www.sciencebase.gov/directory/person/58319
# https://www.wikidata.org/wiki/Q56438082 https://www.sciencebase.gov/directory/person/2666
# https://www.wikidata.org/wiki/Q57408171 https://www.sciencebase.gov/directory/person/12481
# https://www.wikidata.org/wiki/Q57408197 https://www.sciencebase.gov/directory/person/59222
# https://www.wikidata.org/wiki/Q57408725 https://www.sciencebase.gov/directory/person/10957
# https://www.wikidata.org/wiki/Q57472947 https://www.sciencebase.gov/directory/person/5940
# https://www.wikidata.org/wiki/Q57545016 https://www.sciencebase.gov/directory/person/14464
# https://www.wikidata.org/wiki/Q57818266 https://www.sciencebase.gov/directory/person/10851
# https://www.wikidata.org/wiki/Q57885804 https://www.sciencebase.gov/directory/person/7026
# https://www.wikidata.org/wiki/Q58231755 https://www.sciencebase.gov/directory/person/11533
# https://www.wikidata.org/wiki/Q58340635 https://www.sciencebase.gov/directory/person/1050
# https://www.wikidata.org/wiki/Q59749928 https://www.sciencebase.gov/directory/person/4078
# https://www.wikidata.org/wiki/Q59831841 https://www.sciencebase.gov/directory/person/3329
# https://www.wikidata.org/wiki/Q59832242 https://www.sciencebase.gov/directory/person/2133
# https://www.wikidata.org/wiki/Q59833020 https://www.sciencebase.gov/directory/person/10687
# https://www.wikidata.org/wiki/Q59833206 https://www.sciencebase.gov/directory/person/899
# https://www.wikidata.org/wiki/Q59833802 https://www.sciencebase.gov/directory/person/71144
# https://www.wikidata.org/wiki/Q59834044 https://www.sciencebase.gov/directory/person/24355
# https://www.wikidata.org/wiki/Q59835082 https://www.sciencebase.gov/directory/person/70486
# https://www.wikidata.org/wiki/Q61212931 https://www.sciencebase.gov/directory/person/67273
# https://www.wikidata.org/wiki/Q64763030 https://www.sciencebase.gov/directory/person/16029
# https://www.wikidata.org/wiki/Q97158630 https://www.sciencebase.gov/directory/person/3124
# https://www.wikidata.org/wiki/Q15699424 https://www.sciencebase.gov/directory/person/2057
# https://www.wikidata.org/wiki/Q39049955 https://www.sciencebase.gov/directory/person/3478
# https://www.wikidata.org/wiki/Q41628319 https://www.sciencebase.gov/directory/person/8797
# https://www.wikidata.org/wiki/Q47169644 https://www.sciencebase.gov/directory/person/891
# https://www.wikidata.org/wiki/Q47780265 https://www.sciencebase.gov/directory/person/5709
# https://www.wikidata.org/wiki/Q55112213 https://www.sciencebase.gov/directory/person/64092
# https://www.wikidata.org/wiki/Q56798499 https://www.sciencebase.gov/directory/person/9501
# https://www.wikidata.org/wiki/Q57077931 https://www.sciencebase.gov/directory/person/67396
# https://www.wikidata.org/wiki/Q57408085 https://www.sciencebase.gov/directory/person/6867
# https://www.wikidata.org/wiki/Q57408124 https://www.sciencebase.gov/directory/person/5586
# https://www.wikidata.org/wiki/Q57408370 https://www.sciencebase.gov/directory/person/7260
# https://www.wikidata.org/wiki/Q57408397 https://www.sciencebase.gov/directory/person/5791
# https://www.wikidata.org/wiki/Q57408710 https://www.sciencebase.gov/directory/person/10895
# https://www.wikidata.org/wiki/Q57412745 https://www.sciencebase.gov/directory/person/1016
# https://www.wikidata.org/wiki/Q57414191 https://www.sciencebase.gov/directory/person/5420
# https://www.wikidata.org/wiki/Q57414298 https://www.sciencebase.gov/directory/person/8789
# https://www.wikidata.org/wiki/Q57414503 https://www.sciencebase.gov/directory/person/9562
# https://www.wikidata.org/wiki/Q57415470 https://www.sciencebase.gov/directory/person/68957
# https://www.wikidata.org/wiki/Q57733391 https://www.sciencebase.gov/directory/person/9991
# https://www.wikidata.org/wiki/Q57818257 https://www.sciencebase.gov/directory/person/4117
# https://www.wikidata.org/wiki/Q58643270 https://www.sciencebase.gov/directory/person/6536
# https://www.wikidata.org/wiki/Q59763234 https://www.sciencebase.gov/directory/person/9120
# https://www.wikidata.org/wiki/Q59763298 https://www.sciencebase.gov/directory/person/3742
# https://www.wikidata.org/wiki/Q59831996 https://www.sciencebase.gov/directory/person/6461
# https://www.wikidata.org/wiki/Q59832126 https://www.sciencebase.gov/directory/person/8327
# https://www.wikidata.org/wiki/Q59832240 https://www.sciencebase.gov/directory/person/8425
# https://www.wikidata.org/wiki/Q59832243 https://www.sciencebase.gov/directory/person/24631
# https://www.wikidata.org/wiki/Q59832405 https://www.sciencebase.gov/directory/person/8444
# https://www.wikidata.org/wiki/Q59832722 https://www.sciencebase.gov/directory/person/60951
# https://www.wikidata.org/wiki/Q59832804 https://www.sciencebase.gov/directory/person/65365
# https://www.wikidata.org/wiki/Q59832858 https://www.sciencebase.gov/directory/person/7588
# https://www.wikidata.org/wiki/Q59832882 https://www.sciencebase.gov/directory/person/5876
# https://www.wikidata.org/wiki/Q59833053 https://www.sciencebase.gov/directory/person/6586
# https://www.wikidata.org/wiki/Q59833198 https://www.sciencebase.gov/directory/person/7383
# https://www.wikidata.org/wiki/Q59833254 https://www.sciencebase.gov/directory/person/9603
# https://www.wikidata.org/wiki/Q59833446 https://www.sciencebase.gov/directory/person/910
# https://www.wikidata.org/wiki/Q59833526 https://www.sciencebase.gov/directory/person/11369
# https://www.wikidata.org/wiki/Q59833951 https://www.sciencebase.gov/directory/person/12293
# https://www.wikidata.org/wiki/Q59834112 https://www.sciencebase.gov/directory/person/8552
# https://www.wikidata.org/wiki/Q59834159 https://www.sciencebase.gov/directory/person/8109
# https://www.wikidata.org/wiki/Q59834468 https://www.sciencebase.gov/directory/person/67759
# https://www.wikidata.org/wiki/Q59834574 https://www.sciencebase.gov/directory/person/1175
# https://www.wikidata.org/wiki/Q60522295 https://www.sciencebase.gov/directory/person/3128
# https://www.wikidata.org/wiki/Q61979872 https://www.sciencebase.gov/directory/person/3166
# https://www.wikidata.org/wiki/Q64819721 https://www.sciencebase.gov/directory/person/23979
# https://www.wikidata.org/wiki/Q41144103 https://www.sciencebase.gov/directory/person/57822
# https://www.wikidata.org/wiki/Q43284934 https://www.sciencebase.gov/directory/person/9908
# https://www.wikidata.org/wiki/Q46522234 https://www.sciencebase.gov/directory/person/3461
# https://www.wikidata.org/wiki/Q47340893 https://www.sciencebase.gov/directory/person/5740
# https://www.wikidata.org/wiki/Q56387568 https://www.sciencebase.gov/directory/person/11505
# https://www.wikidata.org/wiki/Q57408180 https://www.sciencebase.gov/directory/person/75694
# https://www.wikidata.org/wiki/Q57408352 https://www.sciencebase.gov/directory/person/6772
# https://www.wikidata.org/wiki/Q57408423 https://www.sciencebase.gov/directory/person/58375
# https://www.wikidata.org/wiki/Q57408625 https://www.sciencebase.gov/directory/person/9569
# https://www.wikidata.org/wiki/Q57408684 https://www.sciencebase.gov/directory/person/68008
# https://www.wikidata.org/wiki/Q57414290 https://www.sciencebase.gov/directory/person/10754
# https://www.wikidata.org/wiki/Q57724658 https://www.sciencebase.gov/directory/person/1657
# https://www.wikidata.org/wiki/Q57777349 https://www.sciencebase.gov/directory/person/4474
# https://www.wikidata.org/wiki/Q57777423 https://www.sciencebase.gov/directory/person/11427
# https://www.wikidata.org/wiki/Q57818279 https://www.sciencebase.gov/directory/person/1
# https://www.wikidata.org/wiki/Q57818297 https://www.sciencebase.gov/directory/person/6282
# https://www.wikidata.org/wiki/Q58065939 https://www.sciencebase.gov/directory/person/9130
# https://www.wikidata.org/wiki/Q58371331 https://www.sciencebase.gov/directory/person/10269
# https://www.wikidata.org/wiki/Q59553929 https://www.sciencebase.gov/directory/person/24318
# https://www.wikidata.org/wiki/Q59751684 https://www.sciencebase.gov/directory/person/9223
# https://www.wikidata.org/wiki/Q59831615 https://www.sciencebase.gov/directory/person/6676
# https://www.wikidata.org/wiki/Q59831633 https://www.sciencebase.gov/directory/person/15418
# https://www.wikidata.org/wiki/Q59831795 https://www.sciencebase.gov/directory/person/653
# https://www.wikidata.org/wiki/Q59831948 https://www.sciencebase.gov/directory/person/5369
# https://www.wikidata.org/wiki/Q59831973 https://www.sciencebase.gov/directory/person/4710
# https://www.wikidata.org/wiki/Q59832030 https://www.sciencebase.gov/directory/person/6583
# ...
# https://www.wikidata.org/wiki/Q59833173 https://www.sciencebase.gov/directory/person/62778
# https://www.wikidata.org/wiki/Q59833234 https://www.sciencebase.gov/directory/person/67606
# https://www.wikidata.org/wiki/Q59834828 https://www.sciencebase.gov/directory/person/7156
# https://www.wikidata.org/wiki/Q59835048 https://www.sciencebase.gov/directory/person/24459
# https://www.wikidata.org/wiki/Q42565502 https://www.sciencebase.gov/directory/person/8310
# https://www.wikidata.org/wiki/Q43169165 https://www.sciencebase.gov/directory/person/2190
# https://www.wikidata.org/wiki/Q44872270 https://www.sciencebase.gov/directory/person/1474
# https://www.wikidata.org/wiki/Q46522213 https://www.sciencebase.gov/directory/person/1529
# https://www.wikidata.org/wiki/Q56433769 https://www.sciencebase.gov/directory/person/2931
# https://www.wikidata.org/wiki/Q56798492 https://www.sciencebase.gov/directory/person/7464
# https://www.wikidata.org/wiki/Q57195859 https://www.sciencebase.gov/directory/person/6771
# https://www.wikidata.org/wiki/Q57408121 https://www.sciencebase.gov/directory/person/70402
# https://www.wikidata.org/wiki/Q57408318 https://www.sciencebase.gov/directory/person/11108
# https://www.wikidata.org/wiki/Q57408416 https://www.sciencebase.gov/directory/person/5844
# https://www.wikidata.org/wiki/Q57408432 https://www.sciencebase.gov/directory/person/9115
# https://www.wikidata.org/wiki/Q57408443 https://www.sciencebase.gov/directory/person/23179
# https://www.wikidata.org/wiki/Q57408535 https://www.sciencebase.gov/directory/person/6141
# https://www.wikidata.org/wiki/Q57605779 https://www.sciencebase.gov/directory/person/1969
# https://www.wikidata.org/wiki/Q57777318 https://www.sciencebase.gov/directory/person/765
# https://www.wikidata.org/wiki/Q57777357 https://www.sciencebase.gov/directory/person/6647
# https://www.wikidata.org/wiki/Q57777407 https://www.sciencebase.gov/directory/person/5164
# https://www.wikidata.org/wiki/Q57821387 https://www.sciencebase.gov/directory/person/6309
# https://www.wikidata.org/wiki/Q57836653 https://www.sciencebase.gov/directory/person/9198
# https://www.wikidata.org/wiki/Q57844535 https://www.sciencebase.gov/directory/person/2745
# https://www.wikidata.org/wiki/Q57845302 https://www.sciencebase.gov/directory/person/13818
# https://www.wikidata.org/wiki/Q57899265 https://www.sciencebase.gov/directory/person/1772
# https://www.wikidata.org/wiki/Q58040422 https://www.sciencebase.gov/directory/person/23535
# https://www.wikidata.org/wiki/Q58220769 https://www.sciencebase.gov/directory/person/8340
# https://www.wikidata.org/wiki/Q59815920 https://www.sciencebase.gov/directory/person/6850
# https://www.wikidata.org/wiki/Q59821959 https://www.sciencebase.gov/directory/person/2654
# https://www.wikidata.org/wiki/Q59832003 https://www.sciencebase.gov/directory/person/4383
# https://www.wikidata.org/wiki/Q59832391 https://www.sciencebase.gov/directory/person/10922
# https://www.wikidata.org/wiki/Q59832494 https://www.sciencebase.gov/directory/person/71843
# https://www.wikidata.org/wiki/Q59832987 https://www.sciencebase.gov/directory/person/2044
# https://www.wikidata.org/wiki/Q59833007 https://www.sciencebase.gov/directory/person/58908
# https://www.wikidata.org/wiki/Q59833192 https://www.sciencebase.gov/directory/person/10105
# https://www.wikidata.org/wiki/Q59833567 https://www.sciencebase.gov/directory/person/7896
# https://www.wikidata.org/wiki/Q59833715 https://www.sciencebase.gov/directory/person/175
# https://www.wikidata.org/wiki/Q59833935 https://www.sciencebase.gov/directory/person/11707
# https://www.wikidata.org/wiki/Q59834092 https://www.sciencebase.gov/directory/person/1470
# https://www.wikidata.org/wiki/Q59834357 https://www.sciencebase.gov/directory/person/6471
# https://www.wikidata.org/wiki/Q59834399 https://www.sciencebase.gov/directory/person/61107
# https://www.wikidata.org/wiki/Q59834451 https://www.sciencebase.gov/directory/person/16275
# https://www.wikidata.org/wiki/Q59834902 https://www.sciencebase.gov/directory/person/8601
# https://www.wikidata.org/wiki/Q61969119 https://www.sciencebase.gov/directory/person/14482
# https://www.wikidata.org/wiki/Q65966005 https://www.sciencebase.gov/directory/person/6742
# https://www.wikidata.org/wiki/Q38601197 https://www.sciencebase.gov/directory/person/15315
# https://www.wikidata.org/wiki/Q42031341 https://www.sciencebase.gov/directory/person/10330
# https://www.wikidata.org/wiki/Q52709153 https://www.sciencebase.gov/directory/person/3877
# https://www.wikidata.org/wiki/Q56876401 https://www.sciencebase.gov/directory/person/8177
# https://www.wikidata.org/wiki/Q57408687 https://www.sciencebase.gov/directory/person/1441
# https://www.wikidata.org/wiki/Q57777381 https://www.sciencebase.gov/directory/person/10592
# https://www.wikidata.org/wiki/Q57957920 https://www.sciencebase.gov/directory/person/4126
# https://www.wikidata.org/wiki/Q58099020 https://www.sciencebase.gov/directory/person/13527
# https://www.wikidata.org/wiki/Q58416997 https://www.sciencebase.gov/directory/person/68101
# https://www.wikidata.org/wiki/Q58444777 https://www.sciencebase.gov/directory/person/4809
# https://www.wikidata.org/wiki/Q58663677 https://www.sciencebase.gov/directory/person/10305
# https://www.wikidata.org/wiki/Q59831802 https://www.sciencebase.gov/directory/person/59290
# https://www.wikidata.org/wiki/Q59831944 https://www.sciencebase.gov/directory/person/10715
# https://www.wikidata.org/wiki/Q59832184 https://www.sciencebase.gov/directory/person/4628
# https://www.wikidata.org/wiki/Q59832200 https://www.sciencebase.gov/directory/person/58328
# https://www.wikidata.org/wiki/Q59832477 https://www.sciencebase.gov/directory/person/10640
# https://www.wikidata.org/wiki/Q59832639 https://www.sciencebase.gov/directory/person/7069
# https://www.wikidata.org/wiki/Q59832658 https://www.sciencebase.gov/directory/person/11221
# https://www.wikidata.org/wiki/Q59832661 https://www.sciencebase.gov/directory/person/9715
# https://www.wikidata.org/wiki/Q59832937 https://www.sciencebase.gov/directory/person/69307
# https://www.wikidata.org/wiki/Q59832968 https://www.sciencebase.gov/directory/person/10341
# https://www.wikidata.org/wiki/Q59833041 https://www.sciencebase.gov/directory/person/3472
# https://www.wikidata.org/wiki/Q59833060 https://www.sciencebase.gov/directory/person/1628
# https://www.wikidata.org/wiki/Q59833075 https://www.sciencebase.gov/directory/person/6668
# https://www.wikidata.org/wiki/Q59833087 https://www.sciencebase.gov/directory/person/418
# https://www.wikidata.org/wiki/Q59833842 https://www.sciencebase.gov/directory/person/10759
# https://www.wikidata.org/wiki/Q59834564 https://www.sciencebase.gov/directory/person/10085
# https://www.wikidata.org/wiki/Q59834639 https://www.sciencebase.gov/directory/person/6409
# https://www.wikidata.org/wiki/Q59834996 https://www.sciencebase.gov/directory/person/73712
# https://www.wikidata.org/wiki/Q59861690 https://www.sciencebase.gov/directory/person/74922
# https://www.wikidata.org/wiki/Q60109170 https://www.sciencebase.gov/directory/person/1912
# https://www.wikidata.org/wiki/Q64819673 https://www.sciencebase.gov/directory/person/66799
# https://www.wikidata.org/wiki/Q69208306 https://www.sciencebase.gov/directory/person/2741
# https://www.wikidata.org/wiki/Q40019869 https://www.sciencebase.gov/directory/person/8334
# https://www.wikidata.org/wiki/Q51548748 https://www.sciencebase.gov/directory/person/8060
# https://www.wikidata.org/wiki/Q56547382 https://www.sciencebase.gov/directory/person/3363
# https://www.wikidata.org/wiki/Q57408376 https://www.sciencebase.gov/directory/person/7206
# https://www.wikidata.org/wiki/Q57408386 https://www.sciencebase.gov/directory/person/5565
# https://www.wikidata.org/wiki/Q57408454 https://www.sciencebase.gov/directory/person/13235
# https://www.wikidata.org/wiki/Q57408594 https://www.sciencebase.gov/directory/person/3783
# https://www.wikidata.org/wiki/Q57408682 https://www.sciencebase.gov/directory/person/11649
# https://www.wikidata.org/wiki/Q57408721 https://www.sciencebase.gov/directory/person/719
# https://www.wikidata.org/wiki/Q57413569 https://www.sciencebase.gov/directory/person/7319
# https://www.wikidata.org/wiki/Q57413650 https://www.sciencebase.gov/directory/person/11605
# https://www.wikidata.org/wiki/Q57414917 https://www.sciencebase.gov/directory/person/3515
# https://www.wikidata.org/wiki/Q57415377 https://www.sciencebase.gov/directory/person/8269
# https://www.wikidata.org/wiki/Q57836697 https://www.sciencebase.gov/directory/person/3764
# https://www.wikidata.org/wiki/Q57836711 https://www.sciencebase.gov/directory/person/16402
# https://www.wikidata.org/wiki/Q57909465 https://www.sciencebase.gov/directory/person/757
# https://www.wikidata.org/wiki/Q57974934 https://www.sciencebase.gov/directory/person/4604
# https://www.wikidata.org/wiki/Q58006099 https://www.sciencebase.gov/directory/person/3368
# https://www.wikidata.org/wiki/Q58337622 https://www.sciencebase.gov/directory/person/9398
# https://www.wikidata.org/wiki/Q58338165 https://www.sciencebase.gov/directory/person/2092
# https://www.wikidata.org/wiki/Q58355837 https://www.sciencebase.gov/directory/person/8818
# https://www.wikidata.org/wiki/Q59762286 https://www.sciencebase.gov/directory/person/59825
# https://www.wikidata.org/wiki/Q59762545 https://www.sciencebase.gov/directory/person/161
# https://www.wikidata.org/wiki/Q59763106 https://www.sciencebase.gov/directory/person/4826
# https://www.wikidata.org/wiki/Q59831647 https://www.sciencebase.gov/directory/person/7753
# https://www.wikidata.org/wiki/Q59831675 https://www.sciencebase.gov/directory/person/7961
# https://www.wikidata.org/wiki/Q59832034 https://www.sciencebase.gov/directory/person/3727
# https://www.wikidata.org/wiki/Q59832092 https://www.sciencebase.gov/directory/person/4043
# https://www.wikidata.org/wiki/Q59832369 https://www.sciencebase.gov/directory/person/9600
# https://www.wikidata.org/wiki/Q59832602 https://www.sciencebase.gov/directory/person/15720
# https://www.wikidata.org/wiki/Q59833049 https://www.sciencebase.gov/directory/person/15711
# https://www.wikidata.org/wiki/Q59833438 https://www.sciencebase.gov/directory/person/1107
# https://www.wikidata.org/wiki/Q59834102 https://www.sciencebase.gov/directory/person/937
# https://www.wikidata.org/wiki/Q60731669 https://www.sciencebase.gov/directory/person/69633
# https://www.wikidata.org/wiki/Q37375074 https://www.sciencebase.gov/directory/person/67354
# https://www.wikidata.org/wiki/Q3814589 https://www.sciencebase.gov/directory/person/4488
# https://www.wikidata.org/wiki/Q42181678 https://www.sciencebase.gov/directory/person/10894
# https://www.wikidata.org/wiki/Q44959574 https://www.sciencebase.gov/directory/person/5032
# https://www.wikidata.org/wiki/Q56969441 https://www.sciencebase.gov/directory/person/68954
# https://www.wikidata.org/wiki/Q57260299 https://www.sciencebase.gov/directory/person/390
# https://www.wikidata.org/wiki/Q57412748 https://www.sciencebase.gov/directory/person/9061
# https://www.wikidata.org/wiki/Q57412761 https://www.sciencebase.gov/directory/person/9747
# https://www.wikidata.org/wiki/Q57413457 https://www.sciencebase.gov/directory/person/562
# https://www.wikidata.org/wiki/Q57734830 https://www.sciencebase.gov/directory/person/5037
# https://www.wikidata.org/wiki/Q57777402 https://www.sciencebase.gov/directory/person/2018
# https://www.wikidata.org/wiki/Q57777410 https://www.sciencebase.gov/directory/person/15826
# https://www.wikidata.org/wiki/Q57777413 https://www.sciencebase.gov/directory/person/3623
# https://www.wikidata.org/wiki/Q57818228 https://www.sciencebase.gov/directory/person/24737
# https://www.wikidata.org/wiki/Q57837539 https://www.sciencebase.gov/directory/person/376
# https://www.wikidata.org/wiki/Q57844923 https://www.sciencebase.gov/directory/person/19395
# https://www.wikidata.org/wiki/Q57845135 https://www.sciencebase.gov/directory/person/15487
# https://www.wikidata.org/wiki/Q58096766 https://www.sciencebase.gov/directory/person/511
# https://www.wikidata.org/wiki/Q58193293 https://www.sciencebase.gov/directory/person/70543
# https://www.wikidata.org/wiki/Q58338151 https://www.sciencebase.gov/directory/person/211
# https://www.wikidata.org/wiki/Q58338166 https://www.sciencebase.gov/directory/person/4112
# https://www.wikidata.org/wiki/Q58422972 https://www.sciencebase.gov/directory/person/4750
# https://www.wikidata.org/wiki/Q58423383 https://www.sciencebase.gov/directory/person/3583
# https://www.wikidata.org/wiki/Q59762524 https://www.sciencebase.gov/directory/person/1109
# https://www.wikidata.org/wiki/Q59762603 https://www.sciencebase.gov/directory/person/1901
# https://www.wikidata.org/wiki/Q59762627 https://www.sciencebase.gov/directory/person/9948
# https://www.wikidata.org/wiki/Q59762921 https://www.sciencebase.gov/directory/person/66582
# https://www.wikidata.org/wiki/Q59831772 https://www.sciencebase.gov/directory/person/7530
# https://www.wikidata.org/wiki/Q59831824 https://www.sciencebase.gov/directory/person/11236
# https://www.wikidata.org/wiki/Q59832085 https://www.sciencebase.gov/directory/person/12332
# https://www.wikidata.org/wiki/Q59832584 https://www.sciencebase.gov/directory/person/219
# https://www.wikidata.org/wiki/Q59832594 https://www.sciencebase.gov/directory/person/4080
# https://www.wikidata.org/wiki/Q59832598 https://www.sciencebase.gov/directory/person/435
# https://www.wikidata.org/wiki/Q59832689 https://www.sciencebase.gov/directory/person/60492
# https://www.wikidata.org/wiki/Q59832698 https://www.sciencebase.gov/directory/person/5350
# https://www.wikidata.org/wiki/Q59833045 https://www.sciencebase.gov/directory/person/64593
# https://www.wikidata.org/wiki/Q59834041 https://www.sciencebase.gov/directory/person/178
# https://www.wikidata.org/wiki/Q59834652 https://www.sciencebase.gov/directory/person/62308
# https://www.wikidata.org/wiki/Q59834953 https://www.sciencebase.gov/directory/person/67285
# https://www.wikidata.org/wiki/Q59834972 https://www.sciencebase.gov/directory/person/59672
# https://www.wikidata.org/wiki/Q60995089 https://www.sciencebase.gov/directory/person/11663
# https://www.wikidata.org/wiki/Q68630131 https://www.sciencebase.gov/directory/person/685
# https://www.wikidata.org/wiki/Q38802717 https://www.sciencebase.gov/directory/person/5729
# https://www.wikidata.org/wiki/Q55187045 https://www.sciencebase.gov/directory/person/14527
# https://www.wikidata.org/wiki/Q55189542 https://www.sciencebase.gov/directory/person/2208
# https://www.wikidata.org/wiki/Q57408147 https://www.sciencebase.gov/directory/person/1395
# https://www.wikidata.org/wiki/Q57414151 https://www.sciencebase.gov/directory/person/65351
# https://www.wikidata.org/wiki/Q57414157 https://www.sciencebase.gov/directory/person/2514
# https://www.wikidata.org/wiki/Q57414340 https://www.sciencebase.gov/directory/person/63590
# https://www.wikidata.org/wiki/Q57414615 https://www.sciencebase.gov/directory/person/7980
# https://www.wikidata.org/wiki/Q57777399 https://www.sciencebase.gov/directory/person/4275
# https://www.wikidata.org/wiki/Q57844733 https://www.sciencebase.gov/directory/person/9998
# https://www.wikidata.org/wiki/Q58360032 https://www.sciencebase.gov/directory/person/11205
# https://www.wikidata.org/wiki/Q58461098 https://www.sciencebase.gov/directory/person/70246
# https://www.wikidata.org/wiki/Q59748522 https://www.sciencebase.gov/directory/person/1758
# https://www.wikidata.org/wiki/Q59831696 https://www.sciencebase.gov/directory/person/70110
# https://www.wikidata.org/wiki/Q59832129 https://www.sciencebase.gov/directory/person/11321
# https://www.wikidata.org/wiki/Q59832173 https://www.sciencebase.gov/directory/person/7320
# https://www.wikidata.org/wiki/Q59832964 https://www.sciencebase.gov/directory/person/3214
# https://www.wikidata.org/wiki/Q59833065 https://www.sciencebase.gov/directory/person/5731
# https://www.wikidata.org/wiki/Q59833585 https://www.sciencebase.gov/directory/person/58772
# https://www.wikidata.org/wiki/Q59834291 https://www.sciencebase.gov/directory/person/9529
# https://www.wikidata.org/wiki/Q59834621 https://www.sciencebase.gov/directory/person/71245
# https://www.wikidata.org/wiki/Q59846664 https://www.sciencebase.gov/directory/person/71405
# 781

# %% [markdown]
# # Observations
# * I was interested in the fact that "date of birth" showed up as a property on some records as that's often one of those "personally identifiable information" bits that we would never even have a property for in our government system. Most of these appear to be of lower than month/year precision, which is something that we can verify programmatically based on how WikiData handles date properties. An interesting case here that I glanced through is David M. Miller (https://www.wikidata.org/wiki/Q57729525, https://www.sciencebase.gov/directory/person/7005) who is now an emeritus scientist in USGS and who I worked with some time ago on a publication.
# * Another interesting case is Luke Iwanowicz (https://www.wikidata.org/wiki/Q42260508, https://www.sciencebase.gov/directory/person/4946). His USGS record indicates that he is an active research ecologist at the Leetown Science Center, but his WikiData record does not indicate that he is an employee of the USGS. A view of the item's WikiData history shows that it has come about through a series of actions from 2017-2020 by both bots and what appear to be individual person edits. When I ran the process to link USGS people with ORCIDs to WikiData identities, I looked at only a match on ORCID and full name and did not filter out anyone who was not affiliated with the USGS in their WikiData record.
# * Another interesting property I hadn't seen previously is "different from." A view there shows a cool disambiguation made in WikiData between the USGS Janet Carter (a Bureau Approving Official; https://www.wikidata.org/wiki/Q57408499 https://www.sciencebase.gov/directory/person/1620) and a Janet Carter in New Zealand in a completely different profession. That's pretty cool! The different from disambiguation was made by a user, Daniel Mietchen, in June 2019 according to the history. That tracks to when Janet Carter from New Zeland was created, pointing to part of the power of the WikiData platform in helping to force disambiguation when items of similar name are added to the graph.
# * A really interesting property that holds a lot of promise for one of our use cases dealing with capacity assessment is "field of work." I looked at records for Robert Stallard (https://www.wikidata.org/wiki/Q58358553 https://www.sciencebase.gov/directory/person/9820), who's a pretty famous ecologist who I believe is still based in Boulder. His WikiData record shows only his affiliation with the Smithsonian and provides field of work identifiers with references to his profile page there - https://stri.si.edu/scientist/robert-stallard. Sweet! We have another connection through to some other mineable asset. The values for field of work are relatively high level in terms of understanding specialties, but they are fully linked to associated depth within Wikipedia, which gives them a bit more weight and added context. In Robert's case, we see that he does work in reforestation among other things, which is a deeper level concept than we're going to see in anything USGS has classified out at this point.
# * Another interesting case is Neal Woodman (https://www.wikidata.org/wiki/Q21339166 https://www.sciencebase.gov/directory/person/11434) who is a zoologist with the Patuxent Wildlife Research Center. Neal's field of work properties include some pretty specific references to species and not just general sciences, which is another interesting dynamic in itself that I'm exploring in WikiData. He links to the family of shrews and similar mammals, [Soricidae](https://www.wikidata.org/wiki/Q41631), which is a fairly specific reference. (I'm also exploring the phenomenon that WikiData has over 570,000 references to ITIS TSN identifiers that are linked to many other identification systems that we're interested in for other work I'm doing on taxa information assembly.) A view of the history of Neal's WikiData record shows that field of work values were added by a [real person](https://www.wikidata.org/wiki/User:Uncommon_fritillary), Diane Shaw, at the Smithsonian's Biodiversity Heritage Library. Cool!
# * MusicBrainz artist ID - That sounds like an interesting property. That led me to discover Lori Phillips (https://www.wikidata.org/wiki/Q59832181 https://www.sciencebase.gov/directory/person/14202), a cartographer with NGTOC in Rolla, MO who also appears to be an accomplished classical musician. That brings up the dynamic of WikiData blending professional and personal connections that our corporate information systems would never accomplish, which will seem like a two-edged sword to some folks, I'm sure. One of the other interesting dynamics in Lori's record is the temporal qualifiers on employer, indicating a role with the Florida Department of Transportation between 2007 and 2009 before starting with USGS. That ability to track affiliation over time is something that we have not even yet tackled well in our internal system, and it may be reasonable to project that information out into a third party platform with a more suitable data model.
# * The member of property is another really interesting one for a number of reasons, including potential to influence our capacity assessment use case. Looking at Sarah Minson as an example (https://www.wikidata.org/wiki/Q59676610 https://www.sciencebase.gov/directory/person/58642), she actually has a number of really interesting properties in play that have come about through bots and humans, including [this user](https://www.wikidata.org/wiki/User:Trilotat) who I encountered already when modifying the USGS record. I can see from the WikiData record that Sarah is one of our [PECASE](https://www.wikidata.org/wiki/Q7241433) scientists, something that is not currently available as structured data anywhere from a USGS source, currently. I have a connection to her doctoral advisor, which opens up another line of inquiry. And two professional society memberships indicate areas for data mining on conference involvement that may or may not have hit official publication channels.
# * And then there's the wonderful, Jayne Belnap (https://www.wikidata.org/wiki/Q68630131 https://www.sciencebase.gov/directory/person/685), also accessed via "member of" claims. Jayne is one of the world's foremost soil ecologists who is currently a USGS senior scientist (and an all together wonderful person to hang out with)! Jayne's record has an interesting dynamic with an image property, something I've seen for others as well. Both "member of" and "award received," in this case, point to useful characteristics that could be used for further data mining.
# * Examining the "described at URL" property led me to look at James Skinner (https://www.wikidata.org/wiki/Q62019888 https://www.sciencebase.gov/directory/person/9537), a research geologist at the USGS Astrogeology Science Center. The URL reference dynamic is an interesting one that we'll have to do some work through in terms of either semantic alignment or some data wrangling. There are many different properties that could have a URL pointing to a resource directly associated with a person and usable for further data mining and info gathering. Having them everywhere could be a real challenge to try and nail down and exploit. One approach I may pursue is to simply go after everything that is a subproperty of [URL](https://www.wikidata.org/wiki/Property:P2699), assuming that most relevant properties have been at least classified to that level, and see if that gets us somewhere. James is also an interesting case (as am I), in that he has a whole lot of aliases listed in his WikiData identity, something else that is quite useful in this type of work. The "official website" property is more well populated for USGS people. A look at the values shows that the majority point to our official staff profiles system, which is unfortunately not on a software-friendly platform currently.
# * A look at USGS people with "ResearchGate profile ID" properties points out that a lot of us have them and maybe begs the question on why we're doing this work if ResearchGate has already figured it out. ResearchGate, Academia.edu, and some other platforms have done some great work in both a lot of this mining work and in providing a platform with enough incentives to get folks interested in direct contributions of links and knowledge connections. Unfortunately, despite the occasional [attempt](https://github.com/kaleguy/scraper-api) at hacking their systems, they are closed, proprietary systems with business models that won't support open access. I'm not aiming to recreate what those guys have done at all, but I do want to explore the limits of what we can get to via linked open data channels and how we can project appropriate parts of our own closed corporate information (not proprietary because of policy but because of a lack of technological attention) out into those channels.
# * And as one last point of curiosity, I was interested to find Barb Ralston (https://www.wikidata.org/wiki/Q14949164 https://www.sciencebase.gov/directory/person/8388), another of our USGS Bureau Approving Officials, via a quite specific property - "botanist author abbreviation." A look at the [history of that property](https://www.wikidata.org/wiki/Property_talk:P428) points to an interesting dynamic that we need to consider as we explore exploiting WikiData for our various use cases. Part of the power of the open dialog that drives everything in the "Wikiverse," is the traceability through the deliberative process. We will need to be equally deliberate in making choices about what properties we advocate for use in expounding on USGS items, leveraging fully the properties, definitions, and constraints being laid down by other WikiData contributors while lending our own expertise and judgment. And there are areas we need to weigh in. For instance, in a conversation sparked by editing the USGS page, I've made a modification to the [DOI prefix](https://www.wikidata.org/wiki/Q18340367)'s formatterUrl parameter to point at a more robust resolver. I also need to weigh in on the single value constraint that WikiDataBots are flagging for that property where I've added both the CrossRef and DataCite DOI ID spaces to our USGS record as that is perfectly legitimate, but to do so, I'll have to reach out to a Ukrainian group that seems to be the main users of that property.
