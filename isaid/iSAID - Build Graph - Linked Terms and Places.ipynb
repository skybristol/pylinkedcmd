# %% [markdown]
# # USGS Thesaurus Terms
# The Science Data Catalog indexing process pulls out terms that are declared in metadata to reference the USGS Thesaurus into their own set of keywords for search faceting. These are expressed through the API and pulled into our graphing process in the sdc_cache process executed previously. The iSAID - Verify Terms in Metadata notebook runs through a process that checks the asserted terms against the full USGS Thesaurus source (including other reference vocabularies included with the Thesaurus) to find those terms that actually do align in some way, building a dataset containing the terms, URLs/identifiers, and scope notes. In this codeblock, we process just these terms into the graph, so that we will only establish confirmed links to defined terms from that source to limit noise in our graph.

# %%
import isaid_helpers
import pandas as pd

# %%
pd.read_csv(isaid_helpers.f_graphable_thesaurus_terms).head()
# Out:
#               term  valid_term  usable_term  code             name parent  \
# 0   mining hazards        True         True   750   mining hazards  548.0
# 1           basins        True         True    95           basins  816.0
# 2  air temperature        True         True    27  air temperature   67.0
# 3       Seismology        True         True  1050       seismology  470.0
# 4            Algae        True         True    29            algae  843.0
#
#                                                scope  \
# 0  Dangerous conditions which result from the ext...
# 1  Bowl-shaped, natural depressions in the surfac...
# 2                                                NaN
# 3  Branch of earth sciences concerned with the st...
# 4  Chlorophyll-bearing primarily aquatic nonvascu...
#
#                                       thesaurus_name  thesaurus_id  \
# 0                                     USGS Thesaurus             2
# 1  Alexandria Digital Library Feature Type Thesaurus             3
# 2                                     USGS Thesaurus             2
# 3                                     USGS Thesaurus             2
# 4                                     USGS Thesaurus             2
#
#                                     possible_sources  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'code': 739, 'name': 'seismology', 'parent':...
# 4                                                NaN
#
#                                                  url
# 0  https://apps.usgs.gov/thesaurus/term-simple.ph...
# 1  https://apps.usgs.gov/thesaurus/term-simple.ph...
# 2  https://apps.usgs.gov/thesaurus/term-simple.ph...
# 3  https://apps.usgs.gov/thesaurus/term-simple.ph...
# 4  https://apps.usgs.gov/thesaurus/term-simple.ph...

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MERGE (t:DefinedSubjectMatter {name: row.name})
            ON CREATE
                SET t.url = row.url,
                t.description = row.scope,
                t.thesaurus_name = row.thesaurus_name
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_thesaurus_terms
    })
# Out:
# CPU times: user 1.06 ms, sys: 2.33 ms, total: 3.39 ms
# Wall time: 383 ms

# %%
pd.read_csv(isaid_helpers.f_graphable_place_names).head()
# Out:
#           term                                   possible_sources  valid_term  \
# 0         TOGO  [{'code': 'fTO', 'name': 'Togo', 'parent': 'fL...        True
# 1   Ronceverte                                                NaN        True
# 2    Arlington  [{'code': 'f51013', 'name': 'Arlington', 'pare...        True
# 3  New Hanover                                                NaN        True
# 4     Moriches                                                NaN        True
#
#    usable_term        code         name    parent                       scope  \
# 0         True         fTO         Togo     fLD50                     country
# 1         True  q38082NEE3   Ronceverte  q38082NE  map quadrangle, 7.5 minute
# 2         True      f51013    Arlington     fUS51                      county
# 3         True      f37129  New Hanover     fUS37                      county
# 4         True  q41074NEB2     Moriches  q41074NE  map quadrangle, 7.5 minute
#
#                              thesaurus_name
# 0  Common geographic areas (USGS Thesaurus)
# 1  Common geographic areas (USGS Thesaurus)
# 2  Common geographic areas (USGS Thesaurus)
# 3  Common geographic areas (USGS Thesaurus)
# 4  Common geographic areas (USGS Thesaurus)

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MERGE (l:Location {name: row.name})
            ON CREATE
                SET l.local_id = row.code,
                l.description = row.scope,
                l.thesaurus_name = row.thesaurus_name
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_place_names
    })
# Out:
# CPU times: user 993 µs, sys: 1.41 ms, total: 2.4 ms
# Wall time: 86.6 ms
