# %%
import isaid_helpers
import requests
import pickle
import click
import datetime
import os
from pylinkedcmd import isaid, utilities
import pandas as pd

# %%
def get_raw_model_items():
    r = requests.get(isaid_helpers.model_catalog_api)
    if r.status_code == 200:
        return r.json()["items"]

# %%
# %%time
if click.confirm('Are you sure you want to bother ScienceBase with a request to get all model items?', default=True):
    model_items = get_raw_model_items()
    pickle.dump(model_items, open(isaid_helpers.f_raw_model_catalog, "wb"))
    print(
        isaid_helpers.f_raw_model_catalog, 
        "CREATED", 
        datetime.datetime.fromtimestamp(os.path.getmtime(isaid_helpers.f_raw_model_catalog))
    )
else:
    model_items = pickle.load(open(isaid_helpers.f_raw_model_catalog, "rb"))
    print("model_items loaded to memory from cache file")
# Out:
# Are you sure you want to bother ScienceBase with a request to get all model items? [Y/n]: Y
# usgs_model_catalog.p CREATED 2021-06-07 16:25:59.385455
# CPU times: user 46.9 ms, sys: 17.3 ms, total: 64.2 ms
# Wall time: 4.92 s

# %%
def graphable_model_items(nodified_models, return_format="list"):
    model_items = [i["properties"] for i in nodified_models]
    
    if return_format == "list":
        return model_items
    elif return_format == "dataframe":
        return pd.DataFrame(model_items)
    
def graphable_model_contacts(nodified_models, return_format="list"):
    all_contacts = list()
    for item in [i for i in nodified_models if "identified_points_of_contact" in i]:
        [i.update({"model_url": item["properties"]["url"]}) for i in item["identified_points_of_contact"]]
        all_contacts.extend(item["identified_points_of_contact"])
        
    if return_format == "list":
        return all_contacts
    elif return_format == "dataframe":
        return pd.DataFrame(all_contacts)

# %%
nodified_model_items = [isaid.model_node_from_sb_item(i) for i in model_items]

# %%
[i["identified_points_of_contact"] for i in nodified_model_items if "identified_points_of_contact" in i]
# Out:
# [[{'node_type': 'Person',
#    'name': 'GS-W FACET',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf14',
#    'date_qualifier': '2020-09-25T21:37:46.156Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_facet@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/78586',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf14'},
#   {'node_type': 'Person',
#    'name': 'Kristina G Hopkins',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf14',
#    'date_qualifier': '2020-09-25T21:37:46.156Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'khopkins@usgs.gov',
#    'orcid': '0000-0003-1699-9384',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/70269',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf14'}],
#  [{'node_type': 'Person',
#    'name': 'Frederick D Day-Lewis',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485782ce25b5135abf24',
#    'date_qualifier': '2020-09-25T21:40:48.281Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'daylewis@usgs.gov',
#    'orcid': '0000-0003-3526-886X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/2384',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485782ce25b5135abf24'}],
#  [{'node_type': 'Person',
#    'name': 'Daniel R Schlaepfer',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf94',
#    'date_qualifier': '2020-12-03T18:58:22.811Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'dschlaepfer@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/78370',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf94'},
#   {'node_type': 'Person',
#    'name': 'John B Bradford',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf94',
#    'date_qualifier': '2020-12-03T18:58:22.811Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jbradford@usgs.gov',
#    'orcid': '0000-0001-9257-6303',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/24226',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf94'},
#   {'node_type': 'Person',
#    'name': 'William Lauenroth',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf94',
#    'date_qualifier': '2020-12-03T18:58:22.811Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'Wlauenro@uwyo.edu',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/59506',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf94'},
#   {'node_type': 'Person',
#    'name': 'Kyle Palmquist',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf94',
#    'date_qualifier': '2020-12-03T18:58:22.811Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'kpalmqu1@uwyo.edu',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/79585',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf94'}],
#  [{'node_type': 'Person',
#    'name': 'Rex L Baum',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa4',
#    'date_qualifier': '2021-01-26T19:27:47.102Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'baum@usgs.gov',
#    'orcid': '0000-0001-5337-1970',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/590',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa4'}],
#  [{'node_type': 'Person',
#    'name': 'Douglas Shinneman',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf84',
#    'date_qualifier': '2021-01-27T21:38:00.989Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'dshinneman@usgs.gov',
#    'orcid': '0000-0002-4909-5181',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/13715',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf84'}],
#  [{'node_type': 'Person',
#    'name': 'Richard R McDonald',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485b82ce25b5135abf4a',
#    'date_qualifier': '2021-01-06T21:33:25.794Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rmcd@usgs.gov',
#    'orcid': '0000-0002-0703-0638',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/6719',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485b82ce25b5135abf4a'}],
#  [{'node_type': 'Person',
#    'name': 'Scott R Charlton',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf78',
#    'date_qualifier': '2020-12-28T18:11:59.274Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'charlton@usgs.gov',
#    'orcid': '0000-0001-7332-3394',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/1722',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf78'},
#   {'node_type': 'Person',
#    'name': 'David L Parkhurst',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf78',
#    'date_qualifier': '2020-12-28T18:11:59.274Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'dlpark@usgs.gov',
#    'orcid': '0000-0003-3348-1544',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/7870',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf78'},
#   {'node_type': 'Person',
#    'name': 'Richard M Webb',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf78',
#    'date_qualifier': '2020-12-28T18:11:59.274Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rmwebb@usgs.gov',
#    'orcid': '0000-0001-9531-2207',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/11018',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf78'}],
#  [{'node_type': 'Person',
#    'name': 'Jessica C Stanton',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485d82ce25b5135abf6c',
#    'date_qualifier': '2020-09-25T18:59:28.469Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jcstanton@usgs.gov',
#    'orcid': '0000-0002-6225-3703',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/63378',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485d82ce25b5135abf6c'}],
#  [{'node_type': 'Person',
#    'name': 'Gabriel Senay',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5f3ee04282ce8df5b6c8c0f0',
#    'date_qualifier': '2020-10-05T16:05:42.518Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'senay@usgs.gov',
#    'orcid': '0000-0002-8810-8539',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9305',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5f3ee04282ce8df5b6c8c0f0'}],
#  [{'node_type': 'Person',
#    'name': 'Jay R Alder',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5ef3952782ced62aaae3ef55',
#    'date_qualifier': '2021-01-27T21:17:09.189Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jalder@usgs.gov',
#    'orcid': '0000-0003-2378-2853',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/60598',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5ef3952782ced62aaae3ef55'}],
#  [{'node_type': 'Person',
#    'name': 'Joseph A Hevesi',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485a82ce25b5135abf3e',
#    'date_qualifier': '2021-01-06T21:32:22.318Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jhevesi@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/4522',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485a82ce25b5135abf3e'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf0a',
#    'date_qualifier': '2021-01-06T21:27:52.702Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf0a'}],
#  [{'node_type': 'Person',
#    'name': 'John C Warner',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf00',
#    'date_qualifier': '2021-02-23T22:22:39.744Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jcwarner@usgs.gov',
#    'orcid': '0000-0002-3734-8903',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/10959',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf00'}],
#  [{'node_type': 'Person',
#    'name': 'Richard M Webb',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfb2',
#    'date_qualifier': '2020-10-05T15:50:56.542Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rmwebb@usgs.gov',
#    'orcid': '0000-0001-9531-2207',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/11018',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfb2'},
#   {'node_type': 'Person',
#    'name': 'David L Parkhurst',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfb2',
#    'date_qualifier': '2020-10-05T15:50:56.542Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'dlpark@usgs.gov',
#    'orcid': '0000-0003-3348-1544',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/7870',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfb2'},
#   {'node_type': 'Person',
#    'name': 'Scott R Charlton',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfb2',
#    'date_qualifier': '2020-10-05T15:50:56.542Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'charlton@usgs.gov',
#    'orcid': '0000-0001-7332-3394',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/1722',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfb2'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485b82ce25b5135abf4e',
#    'date_qualifier': '2021-01-06T21:30:41.853Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485b82ce25b5135abf4e'},
#   {'node_type': 'Person',
#    'name': 'Eric D Swain',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485b82ce25b5135abf4e',
#    'date_qualifier': '2021-01-06T21:30:41.853Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'edswain@usgs.gov',
#    'orcid': '0000-0001-7168-708X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/10133',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485b82ce25b5135abf4e'}],
#  [{'node_type': 'Person',
#    'name': 'Jacob B Lowenstern',
#    'reference': 'https://www.sciencebase.gov/catalog/item/601b1a1ed34edf5c66f0e56d',
#    'date_qualifier': '2021-02-03T21:48:14.363Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jlwnstrn@usgs.gov',
#    'orcid': '0000-0003-0464-7779',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/6282',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/601b1a1ed34edf5c66f0e56d'}],
#  [{'node_type': 'Person',
#    'name': 'Gregory E Granato',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf8c',
#    'date_qualifier': '2020-10-05T16:10:22.127Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'ggranato@usgs.gov',
#    'orcid': '0000-0002-2561-9913',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3849',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf8c'}],
#  [{'node_type': 'Person',
#    'name': 'Jeffrey R Ziegeweid',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485682ce25b5135abf1e',
#    'date_qualifier': '2020-11-05T19:18:13.331Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jrziege@usgs.gov',
#    'orcid': '0000-0001-7797-3044',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/11863',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485682ce25b5135abf1e'}],
#  [{'node_type': 'Person',
#    'name': 'Claudia C Faunt',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf08',
#    'date_qualifier': '2020-12-17T16:47:14.373Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'ccfaunt@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3098',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf08'}],
#  [{'node_type': 'Person',
#    'name': 'Hedeff I Essaid',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf8e',
#    'date_qualifier': '2021-01-06T21:21:29.447Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'hiessaid@usgs.gov',
#    'orcid': '0000-0003-0154-8628',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/2991',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf8e'}],
#  [{'node_type': 'Person',
#    'name': 'Richard Niswonger',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32',
#    'date_qualifier': '2021-01-27T17:47:59.578Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rniswon@usgs.gov',
#    'orcid': '0000-0001-6397-2403',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/7518',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32'},
#   {'node_type': 'Person',
#    'name': 'Andrew T Leaf',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32',
#    'date_qualifier': '2021-01-27T17:47:59.578Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'aleaf@usgs.gov',
#    'orcid': '0000-0001-8784-4924',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/60600',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32'},
#   {'node_type': 'Person',
#    'name': 'Robert S Regan',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32',
#    'date_qualifier': '2021-01-27T17:47:59.578Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rsregan@usgs.gov',
#    'orcid': '0000-0003-4803-8596',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8489',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32'},
#   {'node_type': 'Person',
#    'name': 'Steven L Markstrom',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32',
#    'date_qualifier': '2021-01-27T17:47:59.578Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'markstro@usgs.gov',
#    'orcid': '0000-0001-7630-9547',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/6505',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32'},
#   {'node_type': 'Person',
#    'name': 'David E Prudic',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32',
#    'date_qualifier': '2021-01-27T17:47:59.578Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'deprudic@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8316',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32'},
#   {'node_type': 'Person',
#    'name': 'Paul M Barlow',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32',
#    'date_qualifier': '2021-01-27T17:47:59.578Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'pbarlow@usgs.gov',
#    'orcid': '0000-0003-4247-6456',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/504',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf32'}],
#  [{'node_type': 'Person',
#    'name': 'Richard W Healy',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfac',
#    'date_qualifier': '2021-01-27T20:36:02.052Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rwhealy@usgs.gov',
#    'orcid': '0000-0002-0224-1858',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/4383',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfac'}],
#  [{'node_type': 'Person',
#    'name': 'Steve P Schilling',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485a82ce25b5135abf44',
#    'date_qualifier': '2021-01-27T16:50:30.826Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'sschilli@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9108',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485a82ce25b5135abf44'}],
#  [{'node_type': 'Person',
#    'name': 'D Kirk Nordstrom',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfb0',
#    'date_qualifier': '2021-01-28T18:53:22.569Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'dkn@usgs.gov',
#    'orcid': '0000-0003-3283-5136',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/7543',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfb0'}],
#  [{'node_type': 'Person',
#    'name': 'Alexa McKerrow',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5f62520582ce38aaa236154d',
#    'date_qualifier': '2021-01-28T21:07:49.369Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'amckerrow@usgs.gov',
#    'orcid': '0000-0002-8312-2905',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/6780',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5f62520582ce38aaa236154d'},
#   {'node_type': 'Person',
#    'name': 'Julie S Prior-Magee',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5f62520582ce38aaa236154d',
#    'date_qualifier': '2021-01-28T21:07:49.369Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jpmagee@usgs.gov',
#    'orcid': '0000-0003-4031-1885',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8296',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5f62520582ce38aaa236154d'}],
#  [{'node_type': 'Person',
#    'name': 'Benjamin M Sleeter',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485a82ce25b5135abf48',
#    'date_qualifier': '2021-02-22T22:18:19.212Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'bsleeter@usgs.gov',
#    'orcid': '0000-0003-2371-9571',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9561',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485a82ce25b5135abf48'}],
#  [{'node_type': 'Person',
#    'name': 'Kirstie L Haynie',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf90',
#    'date_qualifier': '2020-10-14T01:55:57.033Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'khaynie@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/77955',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf90'},
#   {'node_type': 'Person',
#    'name': 'Gavin Hayes',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf90',
#    'date_qualifier': '2020-10-14T01:55:57.033Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'ghayes@usgs.gov',
#    'orcid': '0000-0003-3323-0112',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/4354',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf90'}],
#  [{'node_type': 'Person',
#    'name': 'Alison P Appling',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9a',
#    'date_qualifier': '2020-11-13T15:41:22.356Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'aappling@usgs.gov',
#    'orcid': '0000-0003-3638-8572',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/68008',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9a'},
#   {'node_type': 'Person',
#    'name': 'Robert O Hall Jr.',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9a',
#    'date_qualifier': '2020-11-13T15:41:22.356Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'bhall@uwyo.edu',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/75320',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9a'},
#   {'node_type': 'Person',
#    'name': 'Maite Arroita',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9a',
#    'date_qualifier': '2020-11-13T15:41:22.356Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'maite.arroita@ehu.es',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/67670',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9a'},
#   {'node_type': 'Person',
#    'name': 'Charles B Yackulic',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9a',
#    'date_qualifier': '2020-11-13T15:41:22.356Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'cyackulic@usgs.gov',
#    'orcid': '0000-0001-9661-0724',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/58832',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9a'}],
#  [{'node_type': 'Person',
#    'name': 'Jana S Stewart',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5f6240eb82ce38aaa2361498',
#    'date_qualifier': '2020-12-02T16:06:42.221Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jsstewar@usgs.gov',
#    'orcid': '0000-0002-8121-1373',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9939',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5f6240eb82ce38aaa2361498'},
#   {'node_type': 'Person',
#    'name': 'Daniel  Wieferich',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5f6240eb82ce38aaa2361498',
#    'date_qualifier': '2020-12-02T16:06:42.221Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'wieferi9@msu.edu',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61158',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5f6240eb82ce38aaa2361498'}],
#  [{'node_type': 'Person',
#    'name': 'GS-CAWSC MODFLOW OWHM',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf8a',
#    'date_qualifier': '2020-12-02T16:53:19.133Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'modflow_owhm@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/66925',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf8a'}],
#  [{'node_type': 'Person',
#    'name': 'Nathalie Voisin',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5f9982a7d34e198cb782b06c',
#    'date_qualifier': '2020-11-25T18:51:37.852Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/52369',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5f9982a7d34e198cb782b06c'}],
#  [{'node_type': 'Person',
#    'name': 'John Karl Bohlke',
#    'reference': 'https://www.sciencebase.gov/catalog/item/60244291d34eb1203113883a',
#    'date_qualifier': '2021-02-10T20:31:13.403Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jkbohlke@usgs.gov',
#    'orcid': '0000-0001-5693-6455',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/948',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/60244291d34eb1203113883a'}],
#  [{'node_type': 'Person',
#    'name': 'Patrick Barnard',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf04',
#    'date_qualifier': '2021-02-23T22:17:59.201Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'pbarnard@usgs.gov',
#    'orcid': '0000-0003-1414-6476',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/508',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf04'},
#   {'node_type': 'Person',
#    'name': 'Li Erikson',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf04',
#    'date_qualifier': '2021-02-23T22:17:59.201Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'lerikson@usgs.gov',
#    'orcid': '0000-0002-8607-7695',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/2982',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf04'},
#   {'node_type': 'Person',
#    'name': 'Alan Allwardt',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf04',
#    'date_qualifier': '2021-02-23T22:17:59.201Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'aallwardt@usgs.gov',
#    'orcid': '0000-0003-3596-1963',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/161',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf04'},
#   {'node_type': 'Person',
#    'name': 'Cara A Nadler',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf04',
#    'date_qualifier': '2021-02-23T22:17:59.201Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'cnadler@usgs.gov',
#    'orcid': '0000-0002-8711-7249',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/70689',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf04'}],
#  [{'node_type': 'Person',
#    'name': 'Lynn J Torak',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485b82ce25b5135abf50',
#    'date_qualifier': '2021-01-06T21:32:18.125Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'ljtorak@usgs.gov',
#    'orcid': '0000-0002-6658-0648',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/10469',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485b82ce25b5135abf50'}],
#  [{'node_type': 'Person',
#    'name': 'William Z Savage',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7e',
#    'date_qualifier': '2021-01-27T16:36:30.460Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'savage@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9048',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7e'},
#   {'node_type': 'Person',
#    'name': 'Jeffrey A Coe',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7e',
#    'date_qualifier': '2021-01-27T16:36:30.460Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jcoe@usgs.gov',
#    'orcid': '0000-0002-0842-9608',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/1927',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7e'}],
#  [{'node_type': 'Person',
#    'name': 'Mark D Petersen',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485d82ce25b5135abf6e',
#    'date_qualifier': '2021-01-06T22:24:55.353Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'mpetersen@usgs.gov',
#    'orcid': '0000-0001-8542-3990',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8045',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485d82ce25b5135abf6e'},
#   {'node_type': 'Person',
#    'name': 'Allison M Shumway',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485d82ce25b5135abf6e',
#    'date_qualifier': '2021-01-06T22:24:55.353Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'ashumway@usgs.gov',
#    'orcid': '0000-0003-1142-7141',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/67941',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485d82ce25b5135abf6e'}],
#  [{'node_type': 'Person',
#    'name': 'Francisco J Simoes',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf98',
#    'date_qualifier': '2021-01-06T21:23:08.348Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'frsimoes@usgs.gov',
#    'orcid': '0000-0002-0934-9730',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9488',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf98'}],
#  [{'node_type': 'Person',
#    'name': 'Robert L Runkel',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf70',
#    'date_qualifier': '2021-01-06T21:35:33.830Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'runkel@usgs.gov',
#    'orcid': '0000-0003-3220-481X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8883',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf70'}],
#  [{'node_type': 'Person',
#    'name': 'Kenneth L Kipp',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485982ce25b5135abf3a',
#    'date_qualifier': '2021-01-06T21:31:48.480Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'klkipp@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/5507',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485982ce25b5135abf3a'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485282ce25b5135abef6',
#    'date_qualifier': '2021-01-06T21:06:24.203Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485282ce25b5135abef6'}],
#  [{'node_type': 'Person',
#    'name': 'Thomas R Sando',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7c',
#    'date_qualifier': '2020-10-14T03:37:33.195Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'tsando@usgs.gov',
#    'orcid': '0000-0003-0704-6258',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/23247',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7c'},
#   {'node_type': 'Person',
#    'name': 'Kristin L Jaeger',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7c',
#    'date_qualifier': '2020-10-14T03:37:33.195Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'kjaeger@usgs.gov',
#    'orcid': '0000-0002-1209-8506',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/69865',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7c'},
#   {'node_type': 'Person',
#    'name': 'Kyle W Blasch',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7c',
#    'date_qualifier': '2020-10-14T03:37:33.195Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'kblasch@usgs.gov',
#    'orcid': '0000-0002-0590-0724',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/893',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7c'},
#   {'node_type': 'Person',
#    'name': 'Jason Dunham',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7c',
#    'date_qualifier': '2020-10-14T03:37:33.195Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jdunham@usgs.gov',
#    'orcid': '0000-0002-6268-0633',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/2751',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf7c'}],
#  [{'node_type': 'Person',
#    'name': 'Terry L Sohl',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485682ce25b5135abf20',
#    'date_qualifier': '2021-01-26T17:15:30.207Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'sohl@usgs.gov',
#    'orcid': '0000-0002-9771-4231',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9712',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485682ce25b5135abf20'}],
#  [{'node_type': 'Person',
#    'name': 'David A Saad',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf96',
#    'date_qualifier': '2020-09-25T21:57:38.128Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'dasaad@usgs.gov',
#    'orcid': '0000-0001-6559-6181',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8926',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf96'},
#   {'node_type': 'Person',
#    'name': 'Gregory E Schwarz',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf96',
#    'date_qualifier': '2020-09-25T21:57:38.128Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gschwarz@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9220',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf96'},
#   {'node_type': 'Person',
#    'name': 'Stephen D Preston',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf96',
#    'date_qualifier': '2020-09-25T21:57:38.128Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'spreston@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8281',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf96'}],
#  [{'node_type': 'Person',
#    'name': 'Curt D. Storlazzi',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeee',
#    'date_qualifier': '2020-09-25T18:20:29.775Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'cstorlazzi@usgs.gov',
#    'orcid': '0000-0001-8057-4490',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/10003',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeee'}],
#  [{'node_type': 'Person',
#    'name': 'Eric D Swain',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485082ce25b5135abee3',
#    'date_qualifier': '2020-09-25T21:31:41.967Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'edswain@usgs.gov',
#    'orcid': '0000-0001-7168-708X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/10133',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485082ce25b5135abee3'}],
#  [{'node_type': 'Person',
#    'name': 'Hans F Schwaiger',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abee8',
#    'date_qualifier': '2020-12-23T21:50:06.564Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'hschwaiger@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/16193',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abee8'},
#   {'node_type': 'Person',
#    'name': 'Roger P Denlinger',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abee8',
#    'date_qualifier': '2020-12-23T21:50:06.564Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'roger@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/2458',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abee8'},
#   {'node_type': 'Person',
#    'name': 'Larry G Mastin',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abee8',
#    'date_qualifier': '2020-12-23T21:50:06.564Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'lgmastin@usgs.gov',
#    'orcid': '0000-0002-4795-1992',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/6582',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abee8'}],
#  [{'node_type': 'Organization',
#    'name': 'Landslide Hazards Program',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf92',
#    'date_qualifier': '2021-01-06T20:50:08.208Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/64245',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf92'}],
#  [{'node_type': 'Person',
#    'name': 'Hedeff I Essaid',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abef0',
#    'date_qualifier': '2021-01-06T21:04:04.695Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'hiessaid@usgs.gov',
#    'orcid': '0000-0003-0154-8628',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/2991',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abef0'}],
#  [{'node_type': 'Person',
#    'name': 'Paul A Hsieh',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf74',
#    'date_qualifier': '2021-01-06T21:13:05.451Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'pahsieh@usgs.gov',
#    'orcid': '0000-0003-4873-4874',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/4788',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf74'}],
#  [{'node_type': 'Organization',
#    'name': 'Nevada Water Science Center',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485082ce25b5135abee6',
#    'date_qualifier': '2021-01-06T21:04:40.135Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/17450',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485082ce25b5135abee6'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfba',
#    'date_qualifier': '2021-01-06T21:26:40.587Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfba'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf1a',
#    'date_qualifier': '2021-01-06T21:24:55.856Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf1a'},
#   {'node_type': 'Person',
#    'name': 'Janice M Fulford',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf1a',
#    'date_qualifier': '2021-01-06T21:24:55.856Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jfulford@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3456',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf1a'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485782ce25b5135abf22',
#    'date_qualifier': '2021-01-06T21:25:24.800Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485782ce25b5135abf22'},
#   {'node_type': 'Person',
#    'name': 'Janice M Fulford',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485782ce25b5135abf22',
#    'date_qualifier': '2021-01-06T21:25:24.800Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jfulford@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3456',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485782ce25b5135abf22'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485982ce25b5135abf38',
#    'date_qualifier': '2021-01-25T22:59:10.253Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485982ce25b5135abf38'}],
#  [{'node_type': 'Person',
#    'name': 'Steven L Markstrom',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf7a',
#    'date_qualifier': '2021-01-26T18:42:21.769Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'markstro@usgs.gov',
#    'orcid': '0000-0001-7630-9547',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/6505',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf7a'},
#   {'node_type': 'Person',
#    'name': 'Robert S Regan',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf7a',
#    'date_qualifier': '2021-01-26T18:42:21.769Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rsregan@usgs.gov',
#    'orcid': '0000-0003-4803-8596',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8489',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf7a'}],
#  [{'node_type': 'Person',
#    'name': 'John R Sauer',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeea',
#    'date_qualifier': '2021-01-28T18:24:19.606Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jrsauer@usgs.gov',
#    'orcid': '0000-0002-4557-3019',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9038',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeea'},
#   {'node_type': 'Person',
#    'name': 'Shannon Beliew',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeea',
#    'date_qualifier': '2021-01-28T18:24:19.606Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'sbeliew@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/15247',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeea'}],
#  [{'node_type': 'Person',
#    'name': 'Timothy J Fox',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf02',
#    'date_qualifier': '2021-01-28T20:35:21.626Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'tfox@usgs.gov',
#    'orcid': '0000-0002-6167-3001',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3358',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf02'}],
#  [{'node_type': 'Person',
#    'name': 'Joshua M Taron',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485982ce25b5135abf3c',
#    'date_qualifier': '2020-09-25T18:53:23.170Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jmtaron@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/60088',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485982ce25b5135abf3c'}],
#  [{'node_type': 'Person',
#    'name': 'GS-CAWSC MODFLOW OWHM',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abefe',
#    'date_qualifier': '2020-10-05T15:46:50.111Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'modflow_owhm@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/66925',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abefe'}],
#  [{'node_type': 'Person',
#    'name': 'David L George',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf0c',
#    'date_qualifier': '2020-10-05T15:50:07.859Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'dlgeorge@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3636',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf0c'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485282ce25b5135abef8',
#    'date_qualifier': '2021-01-06T21:06:50.469Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485282ce25b5135abef8'}],
#  [{'node_type': 'Person',
#    'name': 'Richard B Winston',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfae',
#    'date_qualifier': '2021-01-06T21:24:25.607Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rbwinst@usgs.gov',
#    'orcid': '0000-0002-6287-8834',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/11359',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfae'}],
#  [{'node_type': 'Person',
#    'name': 'Robert L Runkel',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485a82ce25b5135abf46',
#    'date_qualifier': '2021-01-06T21:32:47.710Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'runkel@usgs.gov',
#    'orcid': '0000-0003-3220-481X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8883',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485a82ce25b5135abf46'}],
#  [{'node_type': 'Person',
#    'name': 'Wesley Henson',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf06',
#    'date_qualifier': '2021-01-07T17:56:15.408Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'whenson@usgs.gov',
#    'orcid': '0000-0003-4962-5565',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/13397',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf06'},
#   {'node_type': 'Person',
#    'name': 'Richard Niswonger',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf06',
#    'date_qualifier': '2021-01-07T17:56:15.408Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rniswon@usgs.gov',
#    'orcid': '0000-0001-6397-2403',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/7518',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abf06'}],
#  [{'node_type': 'Person',
#    'name': 'Robert M Hirsch',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf12',
#    'date_qualifier': '2020-09-25T21:37:30.795Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rhirsch@usgs.gov',
#    'orcid': '0000-0002-4534-075X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/4591',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485582ce25b5135abf12'}],
#  [{'node_type': 'Person',
#    'name': 'Richard W Healy',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5f036b3f82ce0afb2446e04a',
#    'date_qualifier': '2021-01-27T21:00:00.265Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rwhealy@usgs.gov',
#    'orcid': '0000-0002-0224-1858',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/4383',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5f036b3f82ce0afb2446e04a'}],
#  [{'node_type': 'Person',
#    'name': 'Martin A Briggs',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfaa',
#    'date_qualifier': '2021-01-27T16:39:46.919Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'mbriggs@usgs.gov',
#    'orcid': '0000-0003-3206-4132',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/60112',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfaa'}],
#  [{'node_type': 'Person',
#    'name': 'Rex L Baum',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa8',
#    'date_qualifier': '2021-01-26T21:19:51.356Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'baum@usgs.gov',
#    'orcid': '0000-0001-5337-1970',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/590',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa8'},
#   {'node_type': 'Person',
#    'name': 'William Z Savage',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa8',
#    'date_qualifier': '2021-01-26T21:19:51.356Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'savage@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9048',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa8'},
#   {'node_type': 'Person',
#    'name': 'Jonathan W Godt',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa8',
#    'date_qualifier': '2021-01-26T21:19:51.356Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jgodt@usgs.gov',
#    'orcid': '0000-0002-8737-2493',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3742',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa8'}],
#  [{'node_type': 'Person',
#    'name': 'Gregory J McCabe',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa2',
#    'date_qualifier': '2021-01-06T21:15:26.407Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gmccabe@usgs.gov',
#    'orcid': '0000-0002-9258-2997',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/6652',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa2'},
#   {'node_type': 'Person',
#    'name': 'Steven L Markstrom',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa2',
#    'date_qualifier': '2021-01-06T21:15:26.407Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'markstro@usgs.gov',
#    'orcid': '0000-0001-7630-9547',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/6505',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486182ce25b5135abfa2'}],
#  [{'node_type': 'Person',
#    'name': 'Rex L Baum',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485282ce25b5135abef4',
#    'date_qualifier': '2021-01-07T17:38:42.818Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'baum@usgs.gov',
#    'orcid': '0000-0001-5337-1970',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/590',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485282ce25b5135abef4'}],
#  [{'node_type': 'Person',
#    'name': 'Clifford I Voss',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9c',
#    'date_qualifier': '2020-09-25T21:49:58.703Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'cvoss@usgs.gov',
#    'orcid': '0000-0001-5923-2752',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/10797',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9c'},
#   {'node_type': 'Person',
#    'name': 'Alden Provost',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9c',
#    'date_qualifier': '2020-09-25T21:49:58.703Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'aprovost@usgs.gov',
#    'orcid': '0000-0002-4443-1107',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8314',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9c'}],
#  [{'node_type': 'Person',
#    'name': 'Claudia C Faunt',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeec',
#    'date_qualifier': '2020-09-25T18:16:27.471Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'ccfaunt@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3098',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeec'},
#   {'node_type': 'Person',
#    'name': 'Lorraine E Flint',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeec',
#    'date_qualifier': '2020-09-25T18:16:27.471Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'lflint@usgs.gov',
#    'orcid': '0000-0002-7868-441X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3263',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abeec'}],
#  [{'node_type': 'Person',
#    'name': 'Gabriel Senay',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5efb79ba82ced62aaaf05856',
#    'date_qualifier': '2020-10-05T15:58:57.880Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'senay@usgs.gov',
#    'orcid': '0000-0002-8810-8539',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9305',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5efb79ba82ced62aaaf05856'}],
#  [{'node_type': 'Person',
#    'name': 'Helen Gibbons',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf0e',
#    'date_qualifier': '2020-10-06T15:14:28.376Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'hgibbons@usgs.gov',
#    'orcid': '0000-0002-0213-2862',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/3655',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf0e'}],
#  [{'node_type': 'Person',
#    'name': 'Sara B Levin',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abfa0',
#    'date_qualifier': '2021-03-17T18:44:33.545Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'slevin@usgs.gov',
#    'orcid': '0000-0002-2448-3129',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/1109',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abfa0'}],
#  [{'node_type': 'Person',
#    'name': 'Paul M Barlow',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf80',
#    'date_qualifier': '2021-01-06T21:28:35.376Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'pbarlow@usgs.gov',
#    'orcid': '0000-0003-4247-6456',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/504',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf80'},
#   {'node_type': 'Person',
#    'name': 'Albert T Rutledge',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf80',
#    'date_qualifier': '2021-01-06T21:28:35.376Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'rutledge@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8903',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf80'}],
#  [{'node_type': 'Person',
#    'name': 'Niel Plummer',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5ff73bbbd34ea5387df03a38',
#    'date_qualifier': '2021-01-07T16:59:02.601Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'nplummer@usgs.gov',
#    'orcid': '0000-0002-4020-1013',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8161',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5ff73bbbd34ea5387df03a38'}],
#  [{'node_type': 'Person',
#    'name': 'Jason Rohweder',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf86',
#    'date_qualifier': '2021-01-06T21:25:56.390Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jrohweder@usgs.gov',
#    'orcid': '0000-0001-5131-9773',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8761',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf86'}],
#  [{'node_type': 'Person',
#    'name': 'Nathan J Wood',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf76',
#    'date_qualifier': '2021-01-27T21:27:22.833Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'nwood@usgs.gov',
#    'orcid': '0000-0002-6060-9729',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/11427',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf76'},
#   {'node_type': 'Person',
#    'name': 'Jeanne M Jones',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf76',
#    'date_qualifier': '2021-01-27T21:27:22.833Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jmjones@usgs.gov',
#    'orcid': '0000-0001-7549-9270',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/22632',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf76'}],
#  [{'node_type': 'Person',
#    'name': 'Stephen M Westenbroek',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9e',
#    'date_qualifier': '2021-01-27T20:28:14.438Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'smwesten@usgs.gov',
#    'orcid': '0000-0002-6284-8643',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/11130',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486082ce25b5135abf9e'}],
#  [{'node_type': 'Person',
#    'name': 'Charles B Yackulic',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485782ce25b5135abf28',
#    'date_qualifier': '2020-12-23T22:09:22.378Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'cyackulic@usgs.gov',
#    'orcid': '0000-0001-9661-0724',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/58832',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485782ce25b5135abf28'}],
#  [{'node_type': 'Person',
#    'name': 'Eric D Swain',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abef2',
#    'date_qualifier': '2020-09-25T18:24:59.677Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'edswain@usgs.gov',
#    'orcid': '0000-0001-7168-708X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/10133',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485182ce25b5135abef2'}],
#  [{'node_type': 'Person',
#    'name': 'Scott E Boyce',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485d82ce25b5135abf62',
#    'date_qualifier': '2020-10-05T16:27:24.046Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'seboyce@usgs.gov',
#    'orcid': '0000-0003-0626-9492',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/19850',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485d82ce25b5135abf62'}],
#  [{'node_type': 'Person',
#    'name': 'Erol Kalkan',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf2e',
#    'date_qualifier': '2021-01-13T21:48:24.099Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'ekalkan@usgs.gov',
#    'orcid': '0000-0002-9138-9407',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/12961',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485882ce25b5135abf2e'}],
#  [{'node_type': 'Person',
#    'name': 'Robert L Runkel',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf72',
#    'date_qualifier': '2021-01-06T21:35:11.712Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'runkel@usgs.gov',
#    'orcid': '0000-0003-3220-481X',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/8883',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485e82ce25b5135abf72'}],
#  [{'node_type': 'Person',
#    'name': 'GS-W h2osoft',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf10',
#    'date_qualifier': '2021-01-06T21:26:06.530Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'gs-w_h2osoft@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/61967',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485482ce25b5135abf10'}],
#  [{'node_type': 'Person',
#    'name': 'Peter R Claggett',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abefc',
#    'date_qualifier': '2021-01-27T18:00:39.265Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'pclaggett@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/1828',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485382ce25b5135abefc'}],
#  [{'node_type': 'Person',
#    'name': 'Judy A Horwatich',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfb6',
#    'date_qualifier': '2021-01-28T21:22:41.589Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jahorwat@usgs.gov',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/4732',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4486282ce25b5135abfb6'}],
#  [{'node_type': 'Person',
#    'name': 'Jay R Alder',
#    'reference': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf82',
#    'date_qualifier': '2021-01-27T21:11:37.805Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jalder@usgs.gov',
#    'orcid': '0000-0003-2378-2853',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/60598',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/5eb4485f82ce25b5135abf82'}],
#  [{'node_type': 'Person',
#    'name': 'Joseph D Hughes',
#    'reference': 'https://www.sciencebase.gov/catalog/item/602d7ffbd34eb1203114bdbd',
#    'date_qualifier': '2021-02-17T20:43:39.794Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'jdhughes@usgs.gov',
#    'orcid': '0000-0003-1311-2354',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/4826',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/602d7ffbd34eb1203114bdbd'},
#   {'node_type': 'Person',
#    'name': 'Ward E Sanford',
#    'reference': 'https://www.sciencebase.gov/catalog/item/602d7ffbd34eb1203114bdbd',
#    'date_qualifier': '2021-02-17T20:43:39.794Z',
#    'relationship_type': 'POINT_OF_CONTACT',
#    'email': 'wsanford@usgs.gov',
#    'orcid': '0000-0002-6624-0280',
#    'identifier_sciencebase': 'https://www.sciencebase.gov/directory/person/9003',
#    'model_url': 'https://www.sciencebase.gov/catalog/item/602d7ffbd34eb1203114bdbd'}]]

# %%
graphable_model_contacts(nodified_model_items, return_format="dataframe").head()
# Out:
#   node_type                   name  \
# 0    Person             GS-W FACET
# 1    Person     Kristina G Hopkins
# 2    Person  Frederick D Day-Lewis
# 3    Person    Daniel R Schlaepfer
# 4    Person        John B Bradford
#
#                                            reference  \
# 0  https://www.sciencebase.gov/catalog/item/5eb44...
# 1  https://www.sciencebase.gov/catalog/item/5eb44...
# 2  https://www.sciencebase.gov/catalog/item/5eb44...
# 3  https://www.sciencebase.gov/catalog/item/5eb44...
# 4  https://www.sciencebase.gov/catalog/item/5eb44...
#
#              date_qualifier relationship_type                 email  \
# 0  2020-09-25T21:37:46.156Z  POINT_OF_CONTACT   gs-w_facet@usgs.gov
# 1  2020-09-25T21:37:46.156Z  POINT_OF_CONTACT     khopkins@usgs.gov
# 2  2020-09-25T21:40:48.281Z  POINT_OF_CONTACT     daylewis@usgs.gov
# 3  2020-12-03T18:58:22.811Z  POINT_OF_CONTACT  dschlaepfer@usgs.gov
# 4  2020-12-03T18:58:22.811Z  POINT_OF_CONTACT    jbradford@usgs.gov
#
#                               identifier_sciencebase  \
# 0  https://www.sciencebase.gov/directory/person/7...
# 1  https://www.sciencebase.gov/directory/person/7...
# 2  https://www.sciencebase.gov/directory/person/2384
# 3  https://www.sciencebase.gov/directory/person/7...
# 4  https://www.sciencebase.gov/directory/person/2...
#
#                                            model_url                orcid
# 0  https://www.sciencebase.gov/catalog/item/5eb44...                  NaN
# 1  https://www.sciencebase.gov/catalog/item/5eb44...  0000-0003-1699-9384
# 2  https://www.sciencebase.gov/catalog/item/5eb44...  0000-0003-3526-886X
# 3  https://www.sciencebase.gov/catalog/item/5eb44...                  NaN
# 4  https://www.sciencebase.gov/catalog/item/5eb44...  0000-0001-9257-6303

# %%
for item in nodified_model_items:
    print(item.keys())
# Out:
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_organizations', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_source_repositories', 'identified_datasets'])
# dict_keys(['properties', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_organizations'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references', 'identified_datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'source_repositories', 'identified_datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_organizations', 'identified_points_of_contact', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_datasets', 'source_repositories'])
# dict_keys(['properties', 'points_of_contact', 'identified_points_of_contact', 'organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references', 'identified_datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references', 'identified_references', 'identified_datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'identified_datasets'])
# dict_keys(['properties', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_authors', 'identified_organizations', 'identified_points_of_contact', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references', 'references'])
# dict_keys(['properties', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references'])
# dict_keys(['properties', 'identified_organizations', 'identified_points_of_contact', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations'])
# dict_keys(['properties', 'identified_organizations', 'identified_points_of_contact', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_organizations', 'references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references', 'source_repositories'])
# dict_keys(['properties', 'identified_contributors', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_source_repositories', 'references'])
# dict_keys(['properties', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references', 'source_repositories', 'identified_datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
# dict_keys(['properties', 'identified_organizations', 'identified_points_of_contact'])
# dict_keys(['properties', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_organizations', 'identified_points_of_contact', 'identified_datasets', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_datasets', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'references', 'identified_datasets'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_source_repositories', 'identified_references', 'datasets'])
# dict_keys(['properties', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references', 'source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories'])
# dict_keys(['properties', 'points_of_contact', 'organizations', 'source_repositories', 'identified_source_repositories'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'identified_references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'source_repositories', 'references'])
# dict_keys(['properties', 'identified_points_of_contact', 'identified_organizations', 'identified_references'])
