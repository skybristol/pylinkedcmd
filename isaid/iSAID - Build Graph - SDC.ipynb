# %% [markdown]
# # Datasets
#
# In this stepwise look at a graphing process, we've already encountered some datasets but classed them initially as the more generalized CreativeWork nodes because we hadn't yet followed up to determine more details. In this next codeblock, we pull in the entire USGS Science Data Catalog: the closer to comprehensive open data inventory for the USGS. This is the most massive process we've worked through yet in working to comprehensively graph as much of the USGS as we can reasonably connect to. This is due here to the massive collection of unique keywords represented in this subset of fairly well documented datasets. The SDC indexing process (from source metadata documents into an Elasticsearch index) has done a reasonable job of splitting out place names, defined/referenced terms from a number of thesaurus sources, and undefined terms. The place names and referenced terms will all need further validation to validate that they actually exist in some viable source, but they provide a good start at some probably better collections.
#
# The API source for datasets provides a graph-optimized derivative of the SDC index. It makes a few choices about the concepts needing to be graphed into entities and relationships and lays out arrays of nodes that are identified with a resolvable identifier that our system already knows about vs. those with no resolvable identifier. For the moment, we are only going to process those contacts with resolvable identifiers. For person contacts, we are also only going to build relationships if the entity already exists in our graph from some other source as we don't have enough information from the SDC to determine if we really want those entities in our graph that we can't resolve from one of the routes we are already processing. We're ignoring the unidentified authors at this point as those are going to need some work to disambiguate and resolve to something before we're willing to add them into our graph.

# %%
import isaid_helpers
import pandas as pd

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc).head()
# Out:
#                  sdc_internal_id  \
# 0  USGS:58e3b415e4b09da67997ee01
# 1  USGS:59a03b8ae4b038630d0303d7
# 2  USGS:5a42aff6e4b0d05ee8bbf5f7
# 3  USGS:5b17fc85e4b092d96521969b
# 4  USGS:5b5f51c2e4b006a11f66e9b9
#
#                                                 name  \
# 0  Wells and water-level altitude in the alluvium...
# 1  Tuckahoe Creek stream flow quantity and qualit...
# 2    Low Intensity Land-use Overlap Colorado Plateau
# 3  Estimated daily loads of nutrients, sediment, ...
# 4  Coastwide Reference Monitoring System (CRMS) 2...
#
#                                          description  \
# 0  Points representing locations of wells in whic...
# 1  This posting contains the stream flow and load...
# 2  This dataset represents the spatial overlap in...
# 3  As part of the Great Lakes Restoration Initiat...
# 4  Wetland restoration efforts conducted by the C...
#
#                                 url last_updated
# 0  https://doi.org/10.5066/F71G0JF6     20200814
# 1  https://doi.org/10.5066/F7DB80RP     20200831
# 2  https://doi.org/10.5066/F72J6B1M     20200827
# 3  https://doi.org/10.5066/P9UBQFPJ     20200827
# 4  https://doi.org/10.5066/P90RE64M     20200830

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MERGE (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            ON CREATE
                SET d.name = row.name,
                d.description = row.description,
                d.url = row.url,
                d.last_updated = row.last_updated
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc
    })
# Out:
# CPU times: user 6.82 ms, sys: 5.03 ms, total: 11.9 ms
# Wall time: 5min 18s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_usgs_thesaurus).head()
# Out:
#             entity_type declared_term_source           rel_type  \
# 0  DefinedSubjectMatter       USGS Thesaurus  ADDRESSES_SUBJECT
# 1  DefinedSubjectMatter       USGS Thesaurus  ADDRESSES_SUBJECT
# 2  DefinedSubjectMatter       USGS Thesaurus  ADDRESSES_SUBJECT
# 3  DefinedSubjectMatter       USGS Thesaurus  ADDRESSES_SUBJECT
# 4  DefinedSubjectMatter       USGS Thesaurus  ADDRESSES_SUBJECT
#
#                 term                sdc_internal_id  \
# 0  Groundwater Level  USGS:58e3b415e4b09da67997ee01
# 1       Hydrogeology  USGS:58e3b415e4b09da67997ee01
# 2        groundwater  USGS:58e3b415e4b09da67997ee01
# 3      water quality  USGS:59a03b8ae4b038630d0303d7
# 4        agriculture  USGS:59a03b8ae4b038630d0303d7
#
#                                            reference date_qualifier
# 0  https://data.usgs.gov/datacatalog/data/USGS:58...       20200814
# 1  https://data.usgs.gov/datacatalog/data/USGS:58...       20200814
# 2  https://data.usgs.gov/datacatalog/data/USGS:58...       20200814
# 3  https://data.usgs.gov/datacatalog/data/USGS:59...       20200831
# 4  https://data.usgs.gov/datacatalog/data/USGS:59...       20200831

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            WITH d, row
                MATCH (t:DefinedSubjectMatter {name: row.term})
                MERGE (d)-[dt:ADDRESSES_SUBJECT]-(t)
                    SET dt.reference = row.reference,
                    dt.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_usgs_thesaurus
    })
# Out:
# CPU times: user 13.5 ms, sys: 9.36 ms, total: 22.9 ms
# Wall time: 12min 7s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_md).head()
# Out:
#                  sdc_internal_id  \
# 0  USGS:58e3b415e4b09da67997ee01
# 1  USGS:59a03b8ae4b038630d0303d7
# 2  USGS:5a42aff6e4b0d05ee8bbf5f7
# 3  USGS:5b17fc85e4b092d96521969b
# 4  USGS:5b5f51c2e4b006a11f66e9b9
#
#                                            reference date_qualifier  \
# 0  https://data.usgs.gov/datacatalog/data/USGS:58...       20200814
# 1  https://data.usgs.gov/datacatalog/data/USGS:59...       20200831
# 2  https://data.usgs.gov/datacatalog/data/USGS:5a...       20200827
# 3  https://data.usgs.gov/datacatalog/data/USGS:5b...       20200827
# 4  https://data.usgs.gov/datacatalog/data/USGS:5b...       20200830
#
#            rel_type entity_type                 email  orcid
# 0  POINT_OF_CONTACT      Person     mholmber@usgs.gov    NaN
# 1  POINT_OF_CONTACT      Person      whively@usgs.gov    NaN
# 2  POINT_OF_CONTACT      Person    jbradford@usgs.gov    NaN
# 3  POINT_OF_CONTACT      Person     tdstunte@usgs.gov    NaN
# 4  POINT_OF_CONTACT      Person  couvillionb@usgs.gov    NaN

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            
            WITH d, row
                MATCH (p:Person {email: row.email})
                MERGE (p)-[mc:METADATA_CONTACT]->(d)
                    SET mc.reference = row.reference,
                    mc.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_md
    })
# Out:
# CPU times: user 5.82 ms, sys: 3.37 ms, total: 9.19 ms
# Wall time: 4min 31s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_poc).head()
# Out:
#                  sdc_internal_id  \
# 0  USGS:58e3b415e4b09da67997ee01
# 1  USGS:59a03b8ae4b038630d0303d7
# 2  USGS:5a42aff6e4b0d05ee8bbf5f7
# 3  USGS:5b17fc85e4b092d96521969b
# 4  USGS:5b5f51c2e4b006a11f66e9b9
#
#                                            reference date_qualifier  \
# 0  https://data.usgs.gov/datacatalog/data/USGS:58...       20200814
# 1  https://data.usgs.gov/datacatalog/data/USGS:59...       20200831
# 2  https://data.usgs.gov/datacatalog/data/USGS:5a...       20200827
# 3  https://data.usgs.gov/datacatalog/data/USGS:5b...       20200827
# 4  https://data.usgs.gov/datacatalog/data/USGS:5b...       20200830
#
#            rel_type entity_type                 email  orcid
# 0  METADATA_CONTACT      Person     mholmber@usgs.gov    NaN
# 1  METADATA_CONTACT      Person      whively@usgs.gov    NaN
# 2  METADATA_CONTACT      Person    jbradford@usgs.gov    NaN
# 3  METADATA_CONTACT      Person     djsulliv@usgs.gov    NaN
# 4  METADATA_CONTACT      Person  couvillionb@usgs.gov    NaN

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            
            WITH d, row
                MATCH (p:Person {email: row.email})
                MERGE (p)-[mc:POINT_OF_CONTACT]->(d)
                    SET mc.reference = row.reference,
                    mc.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_poc
    })
# Out:
# CPU times: user 5.02 ms, sys: 4.03 ms, total: 9.05 ms
# Wall time: 4min 13s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_author).head()
# Out:
#                  sdc_internal_id  \
# 0  USGS:58e3b415e4b09da67997ee01
# 1  USGS:5a42aff6e4b0d05ee8bbf5f7
# 2  USGS:5a42aff6e4b0d05ee8bbf5f7
# 3  USGS:5a42aff6e4b0d05ee8bbf5f7
# 4  USGS:5a42aff6e4b0d05ee8bbf5f7
#
#                                            reference date_qualifier  \
# 0  https://data.usgs.gov/datacatalog/data/USGS:58...       20200814
# 1  https://data.usgs.gov/datacatalog/data/USGS:5a...       20200827
# 2  https://data.usgs.gov/datacatalog/data/USGS:5a...       20200827
# 3  https://data.usgs.gov/datacatalog/data/USGS:5a...       20200827
# 4  https://data.usgs.gov/datacatalog/data/USGS:5a...       20200827
#
#     rel_type entity_type  email                orcid
# 0  AUTHOR_OF      Person    NaN  0000-0002-1316-0412
# 1  AUTHOR_OF      Person    NaN  0000-0003-2353-8500
# 2  AUTHOR_OF      Person    NaN  0000-0001-6707-4803
# 3  AUTHOR_OF      Person    NaN  0000-0001-9257-6303
# 4  AUTHOR_OF      Person    NaN  0000-0002-9643-2785

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            
            WITH d, row
                MATCH (p:Person {orcid: row.orcid})
                MERGE (p)-[mc:AUTHOR_OF]->(d)
                    SET mc.reference = row.reference,
                    mc.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_author
    })
# Out:
# CPU times: user 11.7 ms, sys: 6.25 ms, total: 18 ms
# Wall time: 11min 18s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_places).head()
# Out:
#   entity_type declared_term_source         rel_type  \
# 0    Location                  NaN  ADDRESSES_PLACE
# 1    Location                  NaN  ADDRESSES_PLACE
# 2    Location                  NaN  ADDRESSES_PLACE
# 3    Location                  NaN  ADDRESSES_PLACE
# 4    Location                  NaN  ADDRESSES_PLACE
#
#                           term                sdc_internal_id  \
# 0  Colorado headwaters-Plateau  USGS:5a42aff6e4b0d05ee8bbf5f7
# 1                     Colorado  USGS:5a42aff6e4b0d05ee8bbf5f7
# 2                   New Mexico  USGS:5a42aff6e4b0d05ee8bbf5f7
# 3                      Arizona  USGS:5a42aff6e4b0d05ee8bbf5f7
# 4                         Utah  USGS:5a42aff6e4b0d05ee8bbf5f7
#
#                                            reference  date_qualifier
# 0  https://data.usgs.gov/datacatalog/data/USGS:5a...      20200827.0
# 1  https://data.usgs.gov/datacatalog/data/USGS:5a...      20200827.0
# 2  https://data.usgs.gov/datacatalog/data/USGS:5a...      20200827.0
# 3  https://data.usgs.gov/datacatalog/data/USGS:5a...      20200827.0
# 4  https://data.usgs.gov/datacatalog/data/USGS:5a...      20200827.0

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            
            WITH d, row
                MATCH (l:Location {name: row.term})
                MERGE (d)-[pl:ADDRESSES_PLACE]->(l)
                    SET pl.reference = row.reference,
                    pl.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_places
    })
# Out:
# CPU times: user 14.1 ms, sys: 7.55 ms, total: 21.7 ms
# Wall time: 14min 11s
