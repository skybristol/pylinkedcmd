# %% [markdown]
# # Datasets
#
# In this stepwise look at a graphing process, we've already encountered some datasets but classed them initially as the more generalized CreativeWork nodes because we hadn't yet followed up to determine more details. In this next codeblock, we pull in the entire USGS Science Data Catalog: the closer to comprehensive open data inventory for the USGS. This is the most massive process we've worked through yet in working to comprehensively graph as much of the USGS as we can reasonably connect to. This is due here to the massive collection of unique keywords represented in this subset of fairly well documented datasets. The SDC indexing process (from source metadata documents into an Elasticsearch index) has done a reasonable job of splitting out place names, defined/referenced terms from a number of thesaurus sources, and undefined terms. The place names and referenced terms will all need further validation to validate that they actually exist in some viable source, but they provide a good start at some probably better collections.
#
# The API source for datasets provides a graph-optimized derivative of the SDC index. It makes a few choices about the concepts needing to be graphed into entities and relationships and lays out arrays of nodes that are identified with a resolvable identifier that our system already knows about vs. those with no resolvable identifier. For the moment, we are only going to process those contacts with resolvable identifiers. For person contacts, we are also only going to build relationships if the entity already exists in our graph from some other source as we don't have enough information from the SDC to determine if we really want those entities in our graph that we can't resolve from one of the routes we are already processing. We're ignoring the unidentified authors at this point as those are going to need some work to disambiguate and resolve to something before we're willing to add them into our graph.

# %%
import isaid_helpers
import pandas as pd

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc).head()
# Out:
#                  sdc_internal_id  \
# 0                     USGS:ASC10
# 1                    USGS:ASC108
# 2  USGS:5e0a22f8e4b0b207aa0d55ea
# 3  USGS:5835ef59e4b0d9329c801bab
# 4  USGS:5873c447e4b0a829a31e3195
#
#                                                 name  \
# 0  Map images portraying flight paths of low-alti...
# 1  Gulf of Alaska Shelf and Slope Iron and Nitrat...
# 2  Radiometric thermal aerial imagery from unmann...
# 3                        Amite River Flood Map Files
# 4  Digital Orthorectified Aerial Image of Cottonw...
#
#                                          description  \
# 0  Maps portraying the flight paths for low altit...
# 1  These are data from cruises carried out in Apr...
# 2  These digital images were taken over an area o...
# 3  Heavy rainfall occurred across Louisiana durin...
# 4  Orthorectified image from aerial photograph of...
#
#                                                  url last_updated
# 0  http://alaska.usgs.gov/science/subprogram.php?...     20201125
# 1                   https://doi.org/10.5066/F7222S06     20201125
# 2                   https://doi.org/10.5066/P970EQ7D     20200821
# 3                   https://doi.org/10.5066/F7T43R6C     20200821
# 4                https://dx.doi.org/10.5066/F7DZ06GR     20200825

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MERGE (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            ON CREATE
                SET d.name = row.name,
                d.description = row.description,
                d.url = row.url,
                d.last_updated = row.last_updated
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc
    })
# Out:
# CPU times: user 6.74 ms, sys: 4.79 ms, total: 11.5 ms
# Wall time: 5min 7s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_usgs_thesaurus).head()
# Out:
#                              sdc_internal_id       date_qualifier  \
# 0  USGS:f3b2429c-b5b7-442a-bc39-8d8b7cbe3429  2020-09-08T00:00:00
# 1              USGS:5b736251e4b0f5d5787c61df  2020-08-27T00:00:00
# 2              USGS:5e0a22f8e4b0b207aa0d55ea  2020-08-21T00:00:00
# 3              USGS:5873c447e4b0a829a31e3195  2020-08-25T00:00:00
# 4              USGS:58920ec4e4b072a7ac12de7f  2020-08-25T00:00:00
#
#                                            reference  \
# 0  https://data.usgs.gov/datacatalog/data/USGS:f3...
# 1  https://data.usgs.gov/datacatalog/data/USGS:5b...
# 2  https://data.usgs.gov/datacatalog/data/USGS:5e...
# 3  https://data.usgs.gov/datacatalog/data/USGS:58...
# 4  https://data.usgs.gov/datacatalog/data/USGS:58...
#
#                             DefinedSubjectMatter_url  \
# 0  https://apps.usgs.gov/thesaurus/term-simple.ph...
# 1  https://apps.usgs.gov/thesaurus/term-simple.ph...
# 2  https://apps.usgs.gov/thesaurus/term-simple.ph...
# 3  https://apps.usgs.gov/thesaurus/term-simple.ph...
# 4  https://apps.usgs.gov/thesaurus/term-simple.ph...
#
#                  DefinedSubjectMatter_name DefinedSubjectMatter_source  \
# 0  administrative and political boundaries              USGS Thesaurus
# 1  administrative and political boundaries              USGS Thesaurus
# 2                       aerial photography              USGS Thesaurus
# 3                       aerial photography              USGS Thesaurus
# 4                       aerial photography              USGS Thesaurus
#
#                DefinedSubjectMatter_source_reference  \
# 0  https://apps.usgs.gov/thesaurus/thesaurus.php?...
# 1  https://apps.usgs.gov/thesaurus/thesaurus.php?...
# 2  https://apps.usgs.gov/thesaurus/thesaurus.php?...
# 3  https://apps.usgs.gov/thesaurus/thesaurus.php?...
# 4  https://apps.usgs.gov/thesaurus/thesaurus.php?...
#
#   DefinedSubjectMatter_concept_label  \
# 0                USGS_SCIENCE_TOPICS
# 1                USGS_SCIENCE_TOPICS
# 2            USGS_SCIENTIFIC_METHODS
# 3            USGS_SCIENTIFIC_METHODS
# 4            USGS_SCIENTIFIC_METHODS
#
#                     DefinedSubjectMatter_description
# 0  Lines drawn on maps or described in documents ...
# 1  Lines drawn on maps or described in documents ...
# 2  The process of taking pictures with a camera f...
# 3  The process of taking pictures with a camera f...
# 4  The process of taking pictures with a camera f...

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            WITH d, row
                MERGE (t:DefinedSubjectMatter {url: row.DefinedSubjectMatter_url})
                    SET t.name = row.DefinedSubjectMatter_name,
                    t.source = row.DefinedSubjectMatter_source,
                    t.reference = row.DefinedSubjectMatter_reference,
                    t.concept_label = row.DefinedSubjectMatter_concept_label,
                    t.description = row.DefinedSubjectMatter_description
                MERGE (d)-[dt:ADDRESSES_SUBJECT]->(t)
                    SET dt.reference = row.reference,
                    dt.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_usgs_thesaurus
    })
# Out:
# CPU times: user 19.8 ms, sys: 13.6 ms, total: 33.4 ms
# Wall time: 18min 47s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_md).head()
# Out:
#                  sdc_internal_id  \
# 0                     USGS:ASC10
# 1                    USGS:ASC108
# 2  USGS:5e0a22f8e4b0b207aa0d55ea
# 3  USGS:5835ef59e4b0d9329c801bab
# 4  USGS:5873c447e4b0a829a31e3195
#
#                                            reference date_qualifier  \
# 0  https://data.usgs.gov/datacatalog/data/USGS:ASC10       20201125
# 1  https://data.usgs.gov/datacatalog/data/USGS:AS...       20201125
# 2  https://data.usgs.gov/datacatalog/data/USGS:5e...       20200821
# 3  https://data.usgs.gov/datacatalog/data/USGS:58...       20200821
# 4  https://data.usgs.gov/datacatalog/data/USGS:58...       20200825
#
#            rel_type entity_type              email  orcid
# 0  POINT_OF_CONTACT      Person  bmarcot@fs.fed.us    NaN
# 1  POINT_OF_CONTACT      Person  jcrusius@usgs.gov    NaN
# 2  POINT_OF_CONTACT      Person  mcashman@usgs.gov    NaN
# 3  POINT_OF_CONTACT      Person  bbreaker@usgs.gov    NaN
# 4  POINT_OF_CONTACT      Person   dmushet@usgs.gov    NaN

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            
            WITH d, row
                MATCH (p:Person {email: row.email})
                MERGE (p)-[mc:METADATA_CONTACT]->(d)
                    SET mc.reference = row.reference,
                    mc.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_md
    })
# Out:
# CPU times: user 7.18 ms, sys: 5.47 ms, total: 12.7 ms
# Wall time: 6min 8s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_poc).head()
# Out:
#                  sdc_internal_id  \
# 0                     USGS:ASC10
# 1                    USGS:ASC108
# 2  USGS:5e0a22f8e4b0b207aa0d55ea
# 3  USGS:5835ef59e4b0d9329c801bab
# 4  USGS:5873c447e4b0a829a31e3195
#
#                                            reference date_qualifier  \
# 0  https://data.usgs.gov/datacatalog/data/USGS:ASC10       20201125
# 1  https://data.usgs.gov/datacatalog/data/USGS:AS...       20201125
# 2  https://data.usgs.gov/datacatalog/data/USGS:5e...       20200821
# 3  https://data.usgs.gov/datacatalog/data/USGS:58...       20200821
# 4  https://data.usgs.gov/datacatalog/data/USGS:58...       20200825
#
#            rel_type entity_type                         email  orcid
# 0  METADATA_CONTACT      Person             bmarcot@fs.fed.us    NaN
# 1  METADATA_CONTACT      Person             jcrusius@usgs.gov    NaN
# 2  METADATA_CONTACT      Person             mcashman@usgs.gov    NaN
# 3  METADATA_CONTACT      Person             bbreaker@usgs.gov    NaN
# 4  METADATA_CONTACT      Person  //www.npwrc.usgs.gov/contact    NaN

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            
            WITH d, row
                MATCH (p:Person {email: row.email})
                MERGE (p)-[mc:POINT_OF_CONTACT]->(d)
                    SET mc.reference = row.reference,
                    mc.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_poc
    })
# Out:
# CPU times: user 6.08 ms, sys: 3.69 ms, total: 9.77 ms
# Wall time: 4min 45s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_author).head()
# Out:
#                  sdc_internal_id  \
# 0                    USGS:ASC108
# 1  USGS:5e0a22f8e4b0b207aa0d55ea
# 2  USGS:5e0a22f8e4b0b207aa0d55ea
# 3  USGS:58cc167ee4b0849ce97dce32
# 4  USGS:58cc167ee4b0849ce97dce32
#
#                                            reference date_qualifier  \
# 0  https://data.usgs.gov/datacatalog/data/USGS:AS...       20201125
# 1  https://data.usgs.gov/datacatalog/data/USGS:5e...       20200821
# 2  https://data.usgs.gov/datacatalog/data/USGS:5e...       20200821
# 3  https://data.usgs.gov/datacatalog/data/USGS:58...       20200830
# 4  https://data.usgs.gov/datacatalog/data/USGS:58...       20200830
#
#     rel_type entity_type  email                orcid
# 0  AUTHOR_OF      Person    NaN  0000-0003-2554-0831
# 1  AUTHOR_OF      Person    NaN  0000-0002-6635-4309
# 2  AUTHOR_OF      Person    NaN  0000-0003-3797-4207
# 3  AUTHOR_OF      Person    NaN  0000-0003-0110-0284
# 4  AUTHOR_OF      Person    NaN  0000-0002-2834-2243

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            
            WITH d, row
                MATCH (p:Person {orcid: row.orcid})
                MERGE (p)-[mc:AUTHOR_OF]->(d)
                    SET mc.reference = row.reference,
                    mc.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_author
    })
# Out:
# CPU times: user 14.6 ms, sys: 7.39 ms, total: 22 ms
# Wall time: 12min 52s

# %%
pd.read_csv(isaid_helpers.f_graphable_sdc_rels_places).head()
# Out:
#                  sdc_internal_id       date_qualifier  \
# 0  USGS:5cf01a85e4b0b51330e22aa6  2020-08-27T00:00:00
# 1  USGS:5847137ee4b0f34b016ff271  2020-08-31T00:00:00
# 2  USGS:5eb1ca8782cefae35a29c3d3  2020-08-19T00:00:00
# 3  USGS:5c018adae4b0815414cc70bc  2020-09-25T00:00:00
# 4  USGS:5b92cffce4b0702d0e80a2d5  2021-06-01T00:00:00
#
#                                            reference  \
# 0  https://data.usgs.gov/datacatalog/data/USGS:5c...
# 1  https://data.usgs.gov/datacatalog/data/USGS:58...
# 2  https://data.usgs.gov/datacatalog/data/USGS:5e...
# 3  https://data.usgs.gov/datacatalog/data/USGS:5c...
# 4  https://data.usgs.gov/datacatalog/data/USGS:5b...
#
#   DefinedSubjectMatter_name DefinedSubjectMatter_source  \
# 0          Abbeville County        Wikidata US Counties
# 1                       Abu    Wikidata Global Volcanos
# 2      Acadia National Park  Wikidata US National Parks
# 3      Acadia National Park  Wikidata US National Parks
# 4      Acadia National Park  Wikidata US National Parks
#
#      DefinedSubjectMatter_source_reference DefinedSubjectMatter_concept_label  \
# 0       Wikidata county of state instances                          US_COUNTY
# 1      https://www.wikidata.org/wiki/Q8072                      NAMED_VOLCANO
# 2  https://www.wikidata.org/wiki/Q34918903                      NATIONAL_PARK
# 3  https://www.wikidata.org/wiki/Q34918903                      NATIONAL_PARK
# 4  https://www.wikidata.org/wiki/Q34918903                      NATIONAL_PARK
#
#                  DefinedSubjectMatter_url  \
# 0  http://www.wikidata.org/entity/Q306343
# 1  http://www.wikidata.org/entity/Q334728
# 2  http://www.wikidata.org/entity/Q337396
# 3  http://www.wikidata.org/entity/Q337396
# 4  http://www.wikidata.org/entity/Q337396
#
#           DefinedSubjectMatter_description
# 0  county in South Carolina, United States
# 1  mountain in Yamaguchi Prefecture, Japan
# 2   national park in the US state of Maine
# 3   national park in the US state of Maine
# 4   national park in the US state of Maine

# %%
# %%time
with isaid_helpers.graph_driver.session(database=isaid_helpers.graphdb) as session:
    session.run("""
        LOAD CSV WITH HEADERS FROM '%(source_path)s/%(source_file)s' AS row
        WITH row
            MATCH (d:Dataset {sdc_internal_id: row.sdc_internal_id})
            WITH d, row
                MERGE (l:Location {url: row.DefinedSubjectMatter_url})
                ON CREATE
                    SET l.name = row.DefinedSubjectMatter_name,
                    l.source = row.DefinedSubjectMatter_source,
                    l.reference = row.DefinedSubjectMatter_source_reference,
                    l.concept_label = row.DefinedSubjectMatter_concept_label,
                    l.description = row.DefinedSubjectMatter_description
                MERGE (d)-[pl:ADDRESSES_PLACE]->(l)
                    SET pl.reference = row.reference,
                    pl.date_qualifier = row.date_qualifier
    """ % {
        "source_path": isaid_helpers.local_cache_path,
        "source_file": isaid_helpers.f_graphable_sdc_rels_places
    })
# Out:
# CPU times: user 14.8 ms, sys: 8.37 ms, total: 23.2 ms
# Wall time: 13min 5s
